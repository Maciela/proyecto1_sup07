# %%
import pandas as pd

# %% [markdown]
# Ingestar los datos del archivo netflix.csv

# %%
df_Netflix=pd.read_csv("netflix.csv" , sep="," , encoding="utf-8")

# %%
df_Netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df_Netflix.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %%
df_Netflix.count()
# Out:
# show_id         8790
# type            8790
# title           8790
# director        8790
# country         8790
# date_added      8790
# release_year    8790
# rating          8790
# duration        8790
# listed_in       8790
# dtype: int64

# %%
df_Netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %% [markdown]
# Cambiar el tipo de la columna date_added a datetime

# %%
df_Netflix["date_added"]=df_Netflix["date_added"].astype("datetime64")

# %%
df_Netflix.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# dtype: object

# %%
df_Netflix.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %% [markdown]
# Ordenar de mas antiguo a mas reciente usando : ".sort_values(by=['date_added']) "

# %%
df_Netflix_ord=df_Netflix.sort_values(by=['date_added'])

# %%
df_Netflix_ord
# Out:
#      show_id     type                                title  \
# 4253   s5958    Movie                 To and From New York
# 8423   s6612  TV Show                      Dinner for Five
# 4252   s5957    Movie              Just Another Love Story
# 4251   s5956    Movie                             Splatter
# 5381   s7371    Movie          Mad Ron's Prevues from Hell
# ...      ...      ...                                  ...
# 23        s7    Movie     My Little Pony: A New Generation
# 6572      s5  TV Show                         Kota Factory
# 6586     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 6        s10    Movie                         The Starling
# 0         s1    Movie                 Dick Johnson Is Dead
#
#                            director        country date_added  release_year  \
# 4253           Sorin Dan Mihalcescu  United States 2008-01-01          2006
# 8423                      Not Given  United States 2008-02-04          2007
# 4252                   Ole Bornedal        Denmark 2009-05-05          2007
# 4251                      Joe Dante  United States 2009-11-18          2009
# 5381                     Jim Monaco  United States 2010-11-01          1987
# ...                             ...            ...        ...           ...
# 23    Robert Cullen, José Luis Ucha      Not Given 2021-09-24          2021
# 6572                      Not Given          India 2021-09-24          2021
# 6586                      Not Given       Pakistan 2021-09-24          2021
# 6                    Theodore Melfi  United States 2021-09-24          2021
# 0                   Kirsten Johnson  United States 2021-09-25          2020
#
#      rating   duration                                          listed_in
# 4253  TV-MA     81 min              Dramas, Independent Movies, Thrillers
# 8423  TV-MA   1 Season                       Stand-Up Comedy & Talk Shows
# 4252  TV-MA    104 min                       Dramas, International Movies
# 4251  TV-MA     29 min                                      Horror Movies
# 5381     NR     84 min                         Cult Movies, Horror Movies
# ...     ...        ...                                                ...
# 23       PG     91 min                           Children & Family Movies
# 6572  TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
# 6586  TV-MA   1 Season  Crime TV Shows, Docuseries, International TV S...
# 6     PG-13    104 min                                   Comedies, Dramas
# 0     PG-13     90 min                                      Documentaries
#
# [8790 rows x 10 columns]

# %% [markdown]
# Reemplazar en la columna "director" el valor "Not Given" por None

# %%
df_Netflix_ord["director"]
# Out:
# 4253             Sorin Dan Mihalcescu
# 8423                        Not Given
# 4252                     Ole Bornedal
# 4251                        Joe Dante
# 5381                       Jim Monaco
#                     ...
# 23      Robert Cullen, José Luis Ucha
# 6572                        Not Given
# 6586                        Not Given
# 6                      Theodore Melfi
# 0                     Kirsten Johnson
# Name: director, Length: 8790, dtype: object

# %%
df_Netflix_ord["director"]=df_Netflix_ord["director"].replace("Not Given", "None")

# %%
df_Netflix_ord["director"]
# Out:
# 4253             Sorin Dan Mihalcescu
# 8423                             None
# 4252                     Ole Bornedal
# 4251                        Joe Dante
# 5381                       Jim Monaco
#                     ...
# 23      Robert Cullen, José Luis Ucha
# 6572                             None
# 6586                             None
# 6                      Theodore Melfi
# 0                     Kirsten Johnson
# Name: director, Length: 8790, dtype: object

# %% [markdown]
# Usando mascaras dividir en 3 dataframes distintos, "release_year" 2019, 2020, 2021

# %%
#Dataframe correspondiente al año 2019
mask19=df_Netflix_ord[(df_Netflix_ord["release_year"]==2019)]
mask19
# Out:
#      show_id     type                           title          director  \
# 7997   s4846  TV Show            Arrested Development              None
# 7996   s4845  TV Show       Unbreakable Kimmy Schmidt              None
# 5138   s7064    Movie                        Incoming     Eric Zaragosa
# 7816   s4221  TV Show          COMEDIANS of the world              None
# 7815   s4219  TV Show  A Series of Unfortunate Events              None
# ...      ...      ...                             ...               ...
# 46      s166  TV Show                        Oldsters              None
# 43      s122  TV Show                  Hotel Del Luna              None
# 42      s101  TV Show         Tobot Galaxy Detectives              None
# 111      s91    Movie                  Paradise Hills  Alice Waddington
# 40       s88  TV Show                   Titipo Titipo              None
#
#             country date_added  release_year rating    duration  \
# 7997  United States 2018-05-29          2019  TV-MA   5 Seasons
# 7996  United States 2018-05-30          2019  TV-14   4 Seasons
# 5138         Serbia 2018-10-26          2019  TV-MA      89 min
# 7816  United States 2019-01-01          2019  TV-MA  13 Seasons
# 7815  United States 2019-01-01          2019  TV-PG   3 Seasons
# ...             ...        ...           ...    ...         ...
# 46         Pakistan 2021-09-01          2019  TV-MA    1 Season
# 43         Pakistan 2021-09-02          2019  TV-14    1 Season
# 42         Pakistan 2021-09-07          2019  TV-Y7   2 Seasons
# 111           Spain 2021-09-09          2019  TV-MA      95 min
# 40         Pakistan 2021-09-10          2019   TV-Y   2 Seasons
#
#                                               listed_in
# 7997                                        TV Comedies
# 7996                                        TV Comedies
# 5138               Action & Adventure, Sci-Fi & Fantasy
# 7816          Stand-Up Comedy & Talk Shows, TV Comedies
# 7815       Kids' TV, TV Action & Adventure, TV Comedies
# ...                                                 ...
# 46    Crime TV Shows, International TV Shows, Spanis...
# 43    International TV Shows, Romantic TV Shows, TV ...
# 42                                             Kids' TV
# 111                         Sci-Fi & Fantasy, Thrillers
# 40                            Kids' TV, Korean TV Shows
#
# [1030 rows x 10 columns]

# %%
#Dataframe correspondiente al año 2020
mask20=df_Netflix_ord[(df_Netflix_ord["release_year"]==2020)]
mask20
# Out:
#      show_id     type                                              title  \
# 7537   s3434  TV Show                                   The Hook Up Plan
# 7517   s3370  TV Show                                    BoJack Horseman
# 7484   s3288  TV Show                                 Maradona in Mexico
# 7436   s3169  TV Show                                       Fuller House
# 7412   s3076  TV Show                                       Spinning Out
# ...      ...      ...                                                ...
# 6577     s33  TV Show                                      Sex Education
# 36       s35  TV Show                            Tayo and Little Wizards
# 25       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 6574     s18  TV Show                                    Falsa identidad
# 0         s1    Movie                               Dick Johnson Is Dead
#
#                                            director         country  \
# 7537                                           None          France
# 7517                                           None   United States
# 7484                                           None       Argentina
# 7436                                           None   United States
# 7412                                           None   United States
# ...                                             ...             ...
# 6577                                           None  United Kingdom
# 36                                             None        Pakistan
# 25    Pedro de Echave García, Pablo Azorín Williams       Not Given
# 6574                                           None          Mexico
# 0                                   Kirsten Johnson   United States
#
#      date_added  release_year rating   duration  \
# 7537 2019-10-11          2020  TV-MA  2 Seasons
# 7517 2019-10-25          2020  TV-MA  6 Seasons
# 7484 2019-11-13          2020  TV-MA   1 Season
# 7436 2019-12-06          2020  TV-PG  5 Seasons
# 7412 2020-01-01          2020  TV-MA   1 Season
# ...         ...           ...    ...        ...
# 6577 2021-09-17          2020  TV-MA  3 Seasons
# 36   2021-09-17          2020  TV-Y7   1 Season
# 25   2021-09-22          2020  TV-MA     67 min
# 6574 2021-09-22          2020  TV-MA  2 Seasons
# 0    2021-09-25          2020  PG-13     90 min
#
#                                               listed_in
# 7537  International TV Shows, Romantic TV Shows, TV ...
# 7517                                        TV Comedies
# 7484              Docuseries, Spanish-Language TV Shows
# 7436                                        TV Comedies
# 7412                                          TV Dramas
# ...                                                 ...
# 6577  British TV Shows, International TV Shows, TV C...
# 36                                             Kids' TV
# 25                  Documentaries, International Movies
# 6574  Crime TV Shows, Spanish-Language TV Shows, TV ...
# 0                                         Documentaries
#
# [953 rows x 10 columns]

# %%
#Dataframe correspondiente al año 2021
mask21=df_Netflix_ord[(df_Netflix_ord["release_year"]==2021)]
mask21
# Out:
#      show_id     type                                title  \
# 7355   s2921  TV Show                        Love Is Blind
# 6992   s1697  TV Show                         Polly Pocket
# 6948   s1552  TV Show                                Hilda
# 6917   s1456  TV Show        Headspace Guide to Meditation
# 6915   s1449  TV Show                            Cobra Kai
# ...      ...      ...                                  ...
# 17        s4  TV Show                Jailbirds New Orleans
# 23        s7    Movie     My Little Pony: A New Generation
# 6572      s5  TV Show                         Kota Factory
# 6586     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 6        s10    Movie                         The Starling
#
#                            director         country date_added  release_year  \
# 7355                           None   United States 2020-02-13          2021
# 6992                           None          Canada 2020-11-15          2021
# 6948                           None  United Kingdom 2020-12-14          2021
# 6917                           None   United States 2021-01-01          2021
# 6915                           None   United States 2021-01-01          2021
# ...                             ...             ...        ...           ...
# 17                             None        Pakistan 2021-09-24          2021
# 23    Robert Cullen, José Luis Ucha       Not Given 2021-09-24          2021
# 6572                           None           India 2021-09-24          2021
# 6586                           None        Pakistan 2021-09-24          2021
# 6                    Theodore Melfi   United States 2021-09-24          2021
#
#      rating   duration                                          listed_in
# 7355  TV-MA   1 Season                      Reality TV, Romantic TV Shows
# 6992   TV-Y  2 Seasons                                           Kids' TV
# 6948  TV-Y7  2 Seasons                                           Kids' TV
# 6917   TV-G   1 Season                    Docuseries, Science & Nature TV
# 6915  TV-14  3 Seasons      TV Action & Adventure, TV Comedies, TV Dramas
# ...     ...        ...                                                ...
# 17    TV-MA   1 Season                             Docuseries, Reality TV
# 23       PG     91 min                           Children & Family Movies
# 6572  TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
# 6586  TV-MA   1 Season  Crime TV Shows, Docuseries, International TV S...
# 6     PG-13    104 min                                   Comedies, Dramas
#
# [592 rows x 10 columns]

# %% [markdown]
# Transformar los 3 dataframes en 3 diccionarios distintos usando: .reset_index().to_dict(orient="index")

# %%
#Dicionario correspondiente al DataFrame "mask19" 
dic19=mask19.reset_index().to_dict(orient="index")
dic19
# Out:
# {0: {'index': 7997,
#   'show_id': 's4846',
#   'type': 'TV Show',
#   'title': 'Arrested Development',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2018-05-29 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '5 Seasons',
#   'listed_in': 'TV Comedies'},
#  1: {'index': 7996,
#   'show_id': 's4845',
#   'type': 'TV Show',
#   'title': 'Unbreakable Kimmy Schmidt',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2018-05-30 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '4 Seasons',
#   'listed_in': 'TV Comedies'},
#  2: {'index': 5138,
#   'show_id': 's7064',
#   'type': 'Movie',
#   'title': 'Incoming',
#   'director': 'Eric Zaragosa',
#   'country': 'Serbia',
#   'date_added': Timestamp('2018-10-26 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '89 min',
#   'listed_in': 'Action & Adventure, Sci-Fi & Fantasy'},
#  3: {'index': 7816,
#   'show_id': 's4221',
#   'type': 'TV Show',
#   'title': 'COMEDIANS of the world',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '13 Seasons',
#   'listed_in': 'Stand-Up Comedy & Talk Shows, TV Comedies'},
#  4: {'index': 7815,
#   'show_id': 's4219',
#   'type': 'TV Show',
#   'title': 'A Series of Unfortunate Events',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '3 Seasons',
#   'listed_in': "Kids' TV, TV Action & Adventure, TV Comedies"},
#  5: {'index': 3111,
#   'show_id': 's4228',
#   'type': 'TV Show',
#   'title': 'Tidying Up with Marie Kondo',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV'},
#  6: {'index': 7812,
#   'show_id': 's4203',
#   'type': 'TV Show',
#   'title': 'Horrid Henry',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-01-11 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y7',
#   'duration': '2 Seasons',
#   'listed_in': "British TV Shows, Kids' TV, TV Comedies"},
#  7: {'index': 3077,
#   'show_id': 's4204',
#   'type': 'Movie',
#   'title': 'ReMastered: Massacre at the Stadium',
#   'director': 'Bent-Jorgen Perlmutt',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-11 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '65 min',
#   'listed_in': 'Documentaries, Music & Musicals'},
#  8: {'index': 7810,
#   'show_id': 's4201',
#   'type': 'TV Show',
#   'title': 'Friends from College',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-11 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Romantic TV Shows, TV Comedies'},
#  9: {'index': 3079,
#   'show_id': 's4206',
#   'type': 'Movie',
#   'title': 'The Last Laugh',
#   'director': 'Greg Pritikin',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-11 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '99 min',
#   'listed_in': 'Comedies, Dramas'},
#  10: {'index': 3072,
#   'show_id': 's4194',
#   'type': 'Movie',
#   'title': 'Sebastian Maniscalco: Stay Hungry',
#   'director': 'Rik Reinholdtsen',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-15 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '65 min',
#   'listed_in': 'Stand-Up Comedy'},
#  11: {'index': 418,
#   'show_id': 's4185',
#   'type': 'TV Show',
#   'title': 'Trigger Warning with Killer Mike',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-01-18 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Stand-Up Comedy & Talk Shows'},
#  12: {'index': 7806,
#   'show_id': 's4184',
#   'type': 'TV Show',
#   'title': "The World's Most Extraordinary Homes",
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-01-18 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-G',
#   'duration': '3 Seasons',
#   'listed_in': 'British TV Shows, Docuseries, International TV Shows'},
#  13: {'index': 7805,
#   'show_id': 's4179',
#   'type': 'TV Show',
#   'title': "Marvel's The Punisher",
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-18 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Crime TV Shows, TV Action & Adventure, TV Thrillers'},
#  14: {'index': 3062,
#   'show_id': 's4177',
#   'type': 'Movie',
#   'title': 'FYRE: The Greatest Party That Never Happened',
#   'director': 'Chris Smith',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-18 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '98 min',
#   'listed_in': 'Documentaries'},
#  15: {'index': 3063,
#   'show_id': 's4178',
#   'type': 'Movie',
#   'title': 'IO',
#   'director': 'Jonathan Helpert',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-18 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '96 min',
#   'listed_in': 'Dramas, Sci-Fi & Fantasy'},
#  16: {'index': 7804,
#   'show_id': 's4176',
#   'type': 'Movie',
#   'title': 'Close',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-01-18 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '95 min',
#   'listed_in': 'Action & Adventure, International Movies'},
#  17: {'index': 3065,
#   'show_id': 's4182',
#   'type': 'Movie',
#   'title': 'Patria',
#   'director': 'Matías Gueilburt',
#   'country': 'Mexico',
#   'date_added': Timestamp('2019-01-18 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '90 min',
#   'listed_in': 'Documentaries, International Movies'},
#  18: {'index': 7803,
#   'show_id': 's4173',
#   'type': 'TV Show',
#   'title': 'Conversations with a Killer: The Ted Bundy Tapes',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-24 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  19: {'index': 7802,
#   'show_id': 's4171',
#   'type': 'Movie',
#   'title': 'Polar',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-25 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '119 min',
#   'listed_in': 'Action & Adventure, International Movies'},
#  20: {'index': 7800,
#   'show_id': 's4168',
#   'type': 'TV Show',
#   'title': 'Club of Crows',
#   'director': 'None',
#   'country': 'Mexico',
#   'date_added': Timestamp('2019-01-25 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '4 Seasons',
#   'listed_in': 'International TV Shows, Spanish-Language TV Shows, TV Comedies'},
#  21: {'index': 7801,
#   'show_id': 's4169',
#   'type': 'TV Show',
#   'title': 'Examination of Conscience',
#   'director': 'None',
#   'country': 'Spain',
#   'date_added': Timestamp('2019-01-25 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries, International TV Shows'},
#  22: {'index': 3042,
#   'show_id': 's4154',
#   'type': 'Movie',
#   'title': 'Gabriel Fluffy Iglesias: One Show Fits All',
#   'director': 'Manny Rodriguez',
#   'country': 'United States',
#   'date_added': Timestamp('2019-01-29 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '91 min',
#   'listed_in': 'Stand-Up Comedy'},
#  23: {'index': 7793,
#   'show_id': 's4143',
#   'type': 'TV Show',
#   'title': 'Russian Doll',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies, TV Dramas'},
#  24: {'index': 7790,
#   'show_id': 's4138',
#   'type': 'Movie',
#   'title': "Free Rein: Valentine's Day",
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-G',
#   'duration': '51 min',
#   'listed_in': 'Children & Family Movies, Dramas'},
#  25: {'index': 3043,
#   'show_id': 's4147',
#   'type': 'Movie',
#   'title': 'Velvet Buzzsaw',
#   'director': 'Dan Gilroy',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '113 min',
#   'listed_in': 'Dramas, Thrillers'},
#  26: {'index': 7796,
#   'show_id': 's4146',
#   'type': 'Movie',
#   'title': 'True: Happy Hearts Day',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y',
#   'duration': '24 min',
#   'listed_in': 'Children & Family Movies'},
#  27: {'index': 7789,
#   'show_id': 's4133',
#   'type': 'TV Show',
#   'title': 'Romance is a bonus book',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2019-02-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Korean TV Shows, Romantic TV Shows'},
#  28: {'index': 3034,
#   'show_id': 's4129',
#   'type': 'Movie',
#   'title': 'Ray Romano: Right Here, Around the Corner',
#   'director': 'Michael Showalter',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '59 min',
#   'listed_in': 'Stand-Up Comedy'},
#  29: {'index': 7782,
#   'show_id': 's4123',
#   'type': 'TV Show',
#   'title': 'One Day at a Time',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-08 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '3 Seasons',
#   'listed_in': 'TV Comedies'},
#  30: {'index': 3031,
#   'show_id': 's4122',
#   'type': 'Movie',
#   'title': "Kevin Hart's Guide to Black History",
#   'director': 'Tom Stern',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-08 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '63 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  31: {'index': 3032,
#   'show_id': 's4124',
#   'type': 'Movie',
#   'title': 'ReMastered: The Two Killings of Sam Cooke',
#   'director': 'Kelly Duane de la Vega',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-08 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '74 min',
#   'listed_in': 'Documentaries, Music & Musicals'},
#  32: {'index': 3030,
#   'show_id': 's4121',
#   'type': 'Movie',
#   'title': 'High Flying Bird',
#   'director': 'Steven Soderbergh',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-08 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '91 min',
#   'listed_in': 'Dramas, Sports Movies'},
#  33: {'index': 3028,
#   'show_id': 's4116',
#   'type': 'Movie',
#   'title': 'Ken Jeong: You Complete Me, Ho',
#   'director': 'Jon M. Chu',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-14 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '62 min',
#   'listed_in': 'Stand-Up Comedy'},
#  34: {'index': 400,
#   'show_id': 's4110',
#   'type': 'TV Show',
#   'title': 'The 43',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-02-15 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries, International TV Shows'},
#  35: {'index': 399,
#   'show_id': 's4106',
#   'type': 'TV Show',
#   'title': "Larry Charles' Dangerous World of Comedy",
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-02-15 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, TV Comedies'},
#  36: {'index': 3004,
#   'show_id': 's4086',
#   'type': 'Movie',
#   'title': 'Firebrand',
#   'director': 'Aruna Raje',
#   'country': 'India',
#   'date_added': Timestamp('2019-02-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '117 min',
#   'listed_in': 'Dramas, International Movies'},
#  37: {'index': 7772,
#   'show_id': 's4085',
#   'type': 'TV Show',
#   'title': "Chef's Table",
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '6 Seasons',
#   'listed_in': 'Docuseries, Reality TV'},
#  38: {'index': 3006,
#   'show_id': 's4088',
#   'type': 'Movie',
#   'title': 'Paris Is Us',
#   'director': 'Elisabeth Vogler',
#   'country': 'France',
#   'date_added': Timestamp('2019-02-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '84 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies'},
#  39: {'index': 3005,
#   'show_id': 's4087',
#   'type': 'Movie',
#   'title': 'Paddleton',
#   'director': 'Alex Lehmann',
#   'country': 'United States',
#   'date_added': Timestamp('2019-02-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '89 min',
#   'listed_in': 'Comedies, Dramas, Independent Movies'},
#  40: {'index': 397,
#   'show_id': 's4056',
#   'type': 'TV Show',
#   'title': 'Larva Island',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-03-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y7',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV, Korean TV Shows, TV Comedies"},
#  41: {'index': 398,
#   'show_id': 's4057',
#   'type': 'TV Show',
#   'title': 'Losers',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-03-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries'},
#  42: {'index': 2985,
#   'show_id': 's4063',
#   'type': 'Movie',
#   'title': 'The Boy Who Harnessed the Wind',
#   'director': 'Chiwetel Ejiofor',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-03-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '114 min',
#   'listed_in': 'Children & Family Movies, Dramas, Independent Movies'},
#  43: {'index': 7770,
#   'show_id': 's4058',
#   'type': 'TV Show',
#   'title': 'Northern Rescue',
#   'director': 'None',
#   'country': 'Canada',
#   'date_added': Timestamp('2019-03-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'TV Dramas'},
#  44: {'index': 7769,
#   'show_id': 's4055',
#   'type': 'TV Show',
#   'title': 'Cricket Fever: Mumbai Indians',
#   'director': 'None',
#   'country': 'India',
#   'date_added': Timestamp('2019-03-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, International TV Shows'},
#  45: {'index': 2972,
#   'show_id': 's4046',
#   'type': 'Movie',
#   'title': 'The Hard Way',
#   'director': 'Keoni Waxman',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '94 min',
#   'listed_in': 'Action & Adventure'},
#  46: {'index': 2965,
#   'show_id': 's4035',
#   'type': 'Movie',
#   'title': 'Lady J',
#   'director': 'Emmanuel Mouret',
#   'country': 'France',
#   'date_added': Timestamp('2019-03-08 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '111 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies'},
#  47: {'index': 2964,
#   'show_id': 's4034',
#   'type': 'Movie',
#   'title': 'Juanita',
#   'director': 'Clark Johnson',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-08 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '90 min',
#   'listed_in': 'Dramas, Independent Movies, Romantic Movies'},
#  48: {'index': 2966,
#   'show_id': 's4037',
#   'type': 'Movie',
#   'title': 'Walk. Ride. Rodeo.',
#   'director': 'Conor Allyn',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-08 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '100 min',
#   'listed_in': 'Children & Family Movies, Dramas'},
#  49: {'index': 2802,
#   'show_id': 's4026',
#   'type': 'Movie',
#   'title': 'Jimmy Carr: The Best of Ultimate Gold Greatest Hits',
#   'director': 'Brian Klein',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-03-12 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '58 min',
#   'listed_in': 'Stand-Up Comedy'},
#  50: {'index': 2962,
#   'show_id': 's4025',
#   'type': 'Movie',
#   'title': 'Triple Frontier',
#   'director': 'J.C. Chandor',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-13 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '126 min',
#   'listed_in': 'Action & Adventure'},
#  51: {'index': 395,
#   'show_id': 's4016',
#   'type': 'TV Show',
#   'title': 'The Disappearance of Madeleine McCann',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-03-15 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  52: {'index': 2949,
#   'show_id': 's4005',
#   'type': 'Movie',
#   'title': 'Edoardo Ferrario: Temi Caldi',
#   'director': 'Francesco Imperato',
#   'country': 'Italy',
#   'date_added': Timestamp('2019-03-15 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '65 min',
#   'listed_in': 'Stand-Up Comedy'},
#  53: {'index': 7758,
#   'show_id': 's4017',
#   'type': 'TV Show',
#   'title': 'Turn Up Charlie',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-03-15 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, International TV Shows, TV Comedies'},
#  54: {'index': 7755,
#   'show_id': 's4002',
#   'type': 'TV Show',
#   'title': 'Green Door',
#   'director': 'None',
#   'country': 'Taiwan',
#   'date_added': Timestamp('2019-03-17 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Comedies'},
#  55: {'index': 2945,
#   'show_id': 's4000',
#   'type': 'Movie',
#   'title': 'Amy Schumer Growing',
#   'director': 'Amy Schumer',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '61 min',
#   'listed_in': 'Stand-Up Comedy'},
#  56: {'index': 2943,
#   'show_id': 's3996',
#   'type': 'Movie',
#   'title': 'Alexis Viera: A Story of Surviving',
#   'director': 'Luis Ara',
#   'country': 'Uruguay',
#   'date_added': Timestamp('2019-03-20 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '69 min',
#   'listed_in': 'Documentaries, International Movies, Sports Movies'},
#  57: {'index': 7754,
#   'show_id': 's3999',
#   'type': 'TV Show',
#   'title': "My Husband Won't Fit",
#   'director': 'None',
#   'country': 'Japan',
#   'date_added': Timestamp('2019-03-20 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Dramas'},
#  58: {'index': 392,
#   'show_id': 's3988',
#   'type': 'Movie',
#   'title': 'Antoine Griezmann: The Making of a Legend',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-03-21 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '60 min',
#   'listed_in': 'Documentaries, International Movies, Sports Movies'},
#  59: {'index': 7753,
#   'show_id': 's3990',
#   'type': 'TV Show',
#   'title': 'Stay Tuned!',
#   'director': 'None',
#   'country': 'Japan',
#   'date_added': Timestamp('2019-03-21 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Comedies, TV Dramas'},
#  60: {'index': 2936,
#   'show_id': 's3984',
#   'type': 'Movie',
#   'title': 'ReMastered: The Miami Showband Massacre',
#   'director': 'Stuart Sender',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '71 min',
#   'listed_in': 'Documentaries, Music & Musicals'},
#  61: {'index': 2937,
#   'show_id': 's3986',
#   'type': 'Movie',
#   'title': 'The Dirt',
#   'director': 'Jeff Tremaine',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '108 min',
#   'listed_in': 'Comedies, Dramas, Music & Musicals'},
#  62: {'index': 7748,
#   'show_id': 's3980',
#   'type': 'TV Show',
#   'title': "Charlie's Colorforms City",
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV"},
#  63: {'index': 7751,
#   'show_id': 's3987',
#   'type': 'TV Show',
#   'title': 'The OA',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'TV Dramas, TV Mysteries, TV Sci-Fi & Fantasy'},
#  64: {'index': 7750,
#   'show_id': 's3982',
#   'type': 'TV Show',
#   'title': 'Delhi Crime',
#   'director': 'None',
#   'country': 'India',
#   'date_added': Timestamp('2019-03-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  65: {'index': 7749,
#   'show_id': 's3981',
#   'type': 'TV Show',
#   'title': 'Crime Diaries: The Candidate',
#   'director': 'None',
#   'country': 'Mexico',
#   'date_added': Timestamp('2019-03-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, Spanish-Language TV Shows'},
#  66: {'index': 2931,
#   'show_id': 's3975',
#   'type': 'Movie',
#   'title': 'Nate Bargatze: The Tennessee Kid',
#   'director': 'Ryan Polito',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-26 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '61 min',
#   'listed_in': 'Stand-Up Comedy'},
#  67: {'index': 2928,
#   'show_id': 's3968',
#   'type': 'Movie',
#   'title': 'The Legend of Cocaine Island',
#   'director': 'Theo Love',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-29 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '87 min',
#   'listed_in': 'Documentaries'},
#  68: {'index': 4261,
#   'show_id': 's5967',
#   'type': 'Movie',
#   'title': '15-Aug',
#   'director': 'Swapnaneel Jayakar',
#   'country': 'India',
#   'date_added': Timestamp('2019-03-29 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '124 min',
#   'listed_in': 'Comedies, Dramas, Independent Movies'},
#  69: {'index': 2926,
#   'show_id': 's3964',
#   'type': 'Movie',
#   'title': 'Bayonet',
#   'director': 'Kyzza Terrazas',
#   'country': 'Mexico',
#   'date_added': Timestamp('2019-03-29 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '102 min',
#   'listed_in': 'Dramas, International Movies, Sports Movies'},
#  70: {'index': 7745,
#   'show_id': 's3970',
#   'type': 'TV Show',
#   'title': 'Traitors',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-03-29 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, International TV Shows, TV Dramas'},
#  71: {'index': 2925,
#   'show_id': 's3963',
#   'type': 'Movie',
#   'title': '15-Aug',
#   'director': 'Swapnaneel Jayakar',
#   'country': 'India',
#   'date_added': Timestamp('2019-03-29 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '124 min',
#   'listed_in': 'Comedies, Dramas, Independent Movies'},
#  72: {'index': 2927,
#   'show_id': 's3967',
#   'type': 'Movie',
#   'title': 'The Highwaymen',
#   'director': 'John Lee Hancock',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-29 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '132 min',
#   'listed_in': 'Dramas'},
#  73: {'index': 7744,
#   'show_id': 's3966',
#   'type': 'TV Show',
#   'title': 'Santa Clarita Diet',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-29 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'TV Comedies, TV Horror, TV Thrillers'},
#  74: {'index': 7743,
#   'show_id': 's3965',
#   'type': 'TV Show',
#   'title': 'Osmosis',
#   'director': 'None',
#   'country': 'France',
#   'date_added': Timestamp('2019-03-29 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas, TV Mysteries'},
#  75: {'index': 2923,
#   'show_id': 's3960',
#   'type': 'Movie',
#   'title': 'Mercy Black',
#   'director': 'Owen Egerton',
#   'country': 'United States',
#   'date_added': Timestamp('2019-03-31 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '88 min',
#   'listed_in': 'Horror Movies'},
#  76: {'index': 4257,
#   'show_id': 's5962',
#   'type': 'Movie',
#   'title': '706',
#   'director': 'Shravan Kumar',
#   'country': 'India',
#   'date_added': Timestamp('2019-04-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '118 min',
#   'listed_in': 'Horror Movies, International Movies'},
#  77: {'index': 7741,
#   'show_id': 's3959',
#   'type': 'TV Show',
#   'title': 'Ultraman',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Anime Series, International TV Shows'},
#  78: {'index': 2917,
#   'show_id': 's3951',
#   'type': 'Movie',
#   'title': 'Ek Ladki Ko Dekha Toh Aisa Laga',
#   'director': 'Shelly Chopra Dhar',
#   'country': 'India',
#   'date_added': Timestamp('2019-04-02 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '120 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  79: {'index': 2919,
#   'show_id': 's3953',
#   'type': 'Movie',
#   'title': 'Kevin Hart: Irresponsible',
#   'director': 'Leslie Small',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-02 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '60 min',
#   'listed_in': 'Stand-Up Comedy'},
#  80: {'index': 2915,
#   'show_id': 's3948',
#   'type': 'Movie',
#   'title': 'Ricardo Quevedo: Los amargados somos más',
#   'director': 'Fernando Ayllón',
#   'country': 'Colombia',
#   'date_added': Timestamp('2019-04-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '59 min',
#   'listed_in': 'Stand-Up Comedy'},
#  81: {'index': 7738,
#   'show_id': 's3947',
#   'type': 'TV Show',
#   'title': 'Possessed',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2019-04-04 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, Korean TV Shows'},
#  82: {'index': 6303,
#   'show_id': 's8517',
#   'type': 'Movie',
#   'title': 'The Spy Who Fell to Earth',
#   'director': 'Thomas Meadmore',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-04-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '94 min',
#   'listed_in': 'Documentaries, International Movies'},
#  83: {'index': 7733,
#   'show_id': 's3941',
#   'type': 'TV Show',
#   'title': 'Quicksand',
#   'director': 'None',
#   'country': 'Sweden',
#   'date_added': Timestamp('2019-04-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  84: {'index': 7737,
#   'show_id': 's3945',
#   'type': 'TV Show',
#   'title': 'Tijuana',
#   'director': 'None',
#   'country': 'Mexico',
#   'date_added': Timestamp('2019-04-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, Spanish-Language TV Shows'},
#  85: {'index': 7736,
#   'show_id': 's3944',
#   'type': 'TV Show',
#   'title': 'Spirit: Riding Free',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y7',
#   'duration': '8 Seasons',
#   'listed_in': "Kids' TV"},
#  86: {'index': 2911,
#   'show_id': 's3940',
#   'type': 'Movie',
#   'title': 'Petta',
#   'director': 'Karthik Subbaraj',
#   'country': 'India',
#   'date_added': Timestamp('2019-04-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '170 min',
#   'listed_in': 'Action & Adventure, Comedies, Dramas'},
#  87: {'index': 7735,
#   'show_id': 's3943',
#   'type': 'TV Show',
#   'title': 'Roman Empire: Reign of Blood',
#   'director': 'None',
#   'country': 'Canada',
#   'date_added': Timestamp('2019-04-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'Docuseries'},
#  88: {'index': 2912,
#   'show_id': 's3946',
#   'type': 'Movie',
#   'title': 'Unicorn Store',
#   'director': 'Brie Larson',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '92 min',
#   'listed_in': 'Comedies, Dramas, Independent Movies'},
#  89: {'index': 6547,
#   'show_id': 's3939',
#   'type': 'TV Show',
#   'title': 'Our Planet',
#   'director': 'Alastair Fothergill',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-04-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Science & Nature TV'},
#  90: {'index': 4472,
#   'show_id': 's6210',
#   'type': 'Movie',
#   'title': 'Backfire',
#   'director': 'Dave Patten',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '97 min',
#   'listed_in': 'Dramas, Independent Movies, Thrillers'},
#  91: {'index': 2910,
#   'show_id': 's3936',
#   'type': 'Movie',
#   'title': 'Alien Warfare',
#   'director': 'Jeremiah Jones',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '88 min',
#   'listed_in': 'Action & Adventure, Sci-Fi & Fantasy'},
#  92: {'index': 2908,
#   'show_id': 's3934',
#   'type': 'Movie',
#   'title': 'Petta (Telugu Version)',
#   'director': 'Karthik Subbaraj',
#   'country': 'India',
#   'date_added': Timestamp('2019-04-07 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '170 min',
#   'listed_in': 'Action & Adventure, Comedies, Dramas'},
#  93: {'index': 2906,
#   'show_id': 's3930',
#   'type': 'Movie',
#   'title': 'Liss Pereira: Reteniendo líquidos',
#   'director': 'Fernando Ayllón',
#   'country': 'Brazil',
#   'date_added': Timestamp('2019-04-10 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '59 min',
#   'listed_in': 'Stand-Up Comedy'},
#  94: {'index': 2907,
#   'show_id': 's3931',
#   'type': 'Movie',
#   'title': 'The Silence',
#   'director': 'John R. Leonetti',
#   'country': 'Canada',
#   'date_added': Timestamp('2019-04-10 00:00:00'),
#   'release_year': 2019,
#   'rating': 'PG-13',
#   'duration': '91 min',
#   'listed_in': 'Horror Movies, Thrillers'},
#  95: {'index': 7727,
#   'show_id': 's3932',
#   'type': 'TV Show',
#   'title': 'You vs. Wild',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-10 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV, Reality TV, Science & Nature TV"},
#  96: {'index': 2905,
#   'show_id': 's3929',
#   'type': 'TV Show',
#   'title': 'Persona',
#   'director': 'Lee Kyoungmi, Yim Pilsung, Jeon Go-woon, Kim Jong-kwan',
#   'country': 'South Korea',
#   'date_added': Timestamp('2019-04-11 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Korean TV Shows, TV Dramas'},
#  97: {'index': 7726,
#   'show_id': 's3926',
#   'type': 'TV Show',
#   'title': 'Huge in France',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-12 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies'},
#  98: {'index': 7725,
#   'show_id': 's3925',
#   'type': 'Movie',
#   'title': 'Francesco De Carlo: Cose di Questo Mondo',
#   'director': 'None',
#   'country': 'Italy',
#   'date_added': Timestamp('2019-04-12 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '61 min',
#   'listed_in': 'Stand-Up Comedy'},
#  99: {'index': 2904,
#   'show_id': 's3927',
#   'type': 'Movie',
#   'title': 'The Perfect Date',
#   'director': 'Chris Nelson',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-12 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '91 min',
#   'listed_in': 'Comedies, Romantic Movies'},
#  100: {'index': 2901,
#   'show_id': 's3922',
#   'type': 'Movie',
#   'title': 'Who Would You Take to a Deserted Island?',
#   'director': 'Jota Linares',
#   'country': 'Spain',
#   'date_added': Timestamp('2019-04-13 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '94 min',
#   'listed_in': 'Dramas, International Movies'},
#  101: {'index': 7724,
#   'show_id': 's3921',
#   'type': 'TV Show',
#   'title': 'Crazy Ex-Girlfriend',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-13 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '4 Seasons',
#   'listed_in': 'Romantic TV Shows, TV Comedies'},
#  102: {'index': 387,
#   'show_id': 's3910',
#   'type': 'Movie',
#   'title': 'Super Monsters Furever Friends',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-04-16 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y',
#   'duration': '59 min',
#   'listed_in': 'Children & Family Movies'},
#  103: {'index': 2888,
#   'show_id': 's3907',
#   'type': 'Movie',
#   'title': 'Franco Escamilla: Bienvenido al mundo',
#   'director': 'Ulises Valencia',
#   'country': 'Mexico',
#   'date_added': Timestamp('2019-04-17 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '54 min',
#   'listed_in': 'Stand-Up Comedy'},
#  104: {'index': 2890,
#   'show_id': 's3908',
#   'type': 'Movie',
#   'title': 'HOMECOMING: A film by Beyoncé',
#   'director': 'Beyoncé Knowles-Carter',
#   'country': 'Not Given',
#   'date_added': Timestamp('2019-04-17 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '138 min',
#   'listed_in': 'Documentaries, Music & Musicals'},
#  105: {'index': 7720,
#   'show_id': 's3899',
#   'type': 'TV Show',
#   'title': 'Lunatics',
#   'director': 'None',
#   'country': 'Australia',
#   'date_added': Timestamp('2019-04-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Comedies'},
#  106: {'index': 7722,
#   'show_id': 's3902',
#   'type': 'TV Show',
#   'title': 'Rilakkuma and Kaoru',
#   'director': 'None',
#   'country': 'Japan',
#   'date_added': Timestamp('2019-04-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Anime Series, International TV Shows'},
#  107: {'index': 2885,
#   'show_id': 's3904',
#   'type': 'Movie',
#   'title': 'Someone Great',
#   'director': 'Jennifer Kaytin Robinson',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '92 min',
#   'listed_in': 'Comedies, Romantic Movies'},
#  108: {'index': 2886,
#   'show_id': 's3905',
#   'type': 'Movie',
#   'title': 'The Ruthless',
#   'director': 'Renato De Maria',
#   'country': 'Italy',
#   'date_added': Timestamp('2019-04-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '111 min',
#   'listed_in': 'Dramas, International Movies'},
#  109: {'index': 2883,
#   'show_id': 's3897',
#   'type': 'Movie',
#   'title': 'Brené Brown: The Call to Courage',
#   'director': 'Sandra Restrepo',
#   'country': 'Not Given',
#   'date_added': Timestamp('2019-04-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '77 min',
#   'listed_in': 'Documentaries'},
#  110: {'index': 2884,
#   'show_id': 's3900',
#   'type': 'Movie',
#   'title': 'Music Teacher',
#   'director': 'Sarthak Dasgupta',
#   'country': 'India',
#   'date_added': Timestamp('2019-04-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '102 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies'},
#  111: {'index': 7723,
#   'show_id': 's3903',
#   'type': 'TV Show',
#   'title': 'Samantha!',
#   'director': 'None',
#   'country': 'Brazil',
#   'date_added': Timestamp('2019-04-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'International TV Shows, TV Comedies'},
#  112: {'index': 2881,
#   'show_id': 's3896',
#   'type': 'Movie',
#   'title': 'Grass Is Greener',
#   'director': 'Fab Five Freddie',
#   'country': 'Not Given',
#   'date_added': Timestamp('2019-04-20 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '98 min',
#   'listed_in': 'Documentaries, Music & Musicals'},
#  113: {'index': 5349,
#   'show_id': 's7320',
#   'type': 'Movie',
#   'title': 'Little Singham in London',
#   'director': 'Prakash Satam',
#   'country': 'Not Given',
#   'date_added': Timestamp('2019-04-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y7',
#   'duration': '66 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  114: {'index': 2878,
#   'show_id': 's3890',
#   'type': 'Movie',
#   'title': 'Money Trap',
#   'director': 'Yılmaz Erdoğan',
#   'country': 'Turkey',
#   'date_added': Timestamp('2019-04-26 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '122 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  115: {'index': 2880,
#   'show_id': 's3892',
#   'type': 'Movie',
#   'title': 'ReMastered: Devil at the Crossroads',
#   'director': 'Brian Oakes',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-26 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '49 min',
#   'listed_in': 'Documentaries, Music & Musicals'},
#  116: {'index': 7717,
#   'show_id': 's3888',
#   'type': 'TV Show',
#   'title': 'Chambers',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-26 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Horror, TV Mysteries, Teen TV Shows'},
#  117: {'index': 7718,
#   'show_id': 's3893',
#   'type': 'TV Show',
#   'title': 'Street Food',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-26 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries'},
#  118: {'index': 2877,
#   'show_id': 's3889',
#   'type': 'Movie',
#   'title': 'Loving is Losing',
#   'director': 'Fernando Ayllón',
#   'country': 'Colombia',
#   'date_added': Timestamp('2019-04-26 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '91 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies'},
#  119: {'index': 2874,
#   'show_id': 's3878',
#   'type': 'Movie',
#   'title': 'Anthony Jeselnik: Fire in the Maternity Ward',
#   'director': 'Marcus Raboy',
#   'country': 'United States',
#   'date_added': Timestamp('2019-04-30 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '64 min',
#   'listed_in': 'Stand-Up Comedy'},
#  120: {'index': 2873,
#   'show_id': 's3876',
#   'type': 'Movie',
#   'title': 'A Home with A View',
#   'director': 'Herman Yau',
#   'country': 'Hong Kong',
#   'date_added': Timestamp('2019-04-30 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '92 min',
#   'listed_in': 'Comedies, International Movies'},
#  121: {'index': 2872,
#   'show_id': 's3875',
#   'type': 'Movie',
#   'title': 'Sur Sapata',
#   'director': 'Mangesh Kanthale',
#   'country': 'India',
#   'date_added': Timestamp('2019-05-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '140 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  122: {'index': 661,
#   'show_id': 's8377',
#   'type': 'TV Show',
#   'title': 'The Kindness Diaries',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-05-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV'},
#  123: {'index': 2870,
#   'show_id': 's3873',
#   'type': 'Movie',
#   'title': 'Knock Down The House',
#   'director': 'Rachel Lears',
#   'country': 'United States',
#   'date_added': Timestamp('2019-05-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'PG',
#   'duration': '88 min',
#   'listed_in': 'Documentaries'},
#  124: {'index': 7707,
#   'show_id': 's3865',
#   'type': 'TV Show',
#   'title': 'Flinch',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-05-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV'},
#  125: {'index': 2861,
#   'show_id': 's3860',
#   'type': 'Movie',
#   'title': 'All In My Family',
#   'director': 'Hao Wu',
#   'country': 'United States',
#   'date_added': Timestamp('2019-05-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '40 min',
#   'listed_in': 'Documentaries, LGBTQ Movies'},
#  126: {'index': 2862,
#   'show_id': 's3861',
#   'type': 'TV Show',
#   'title': 'Crime Diaries: Night Out',
#   'director': 'Felipe Cano',
#   'country': 'Mexico',
#   'date_added': Timestamp('2019-05-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, Spanish-Language TV Shows'},
#  127: {'index': 2864,
#   'show_id': 's3864',
#   'type': 'Movie',
#   'title': 'Extremely Wicked, Shockingly Evil and Vile',
#   'director': 'Joe Berlinger',
#   'country': 'United States',
#   'date_added': Timestamp('2019-05-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '110 min',
#   'listed_in': 'Dramas, Independent Movies'},
#  128: {'index': 7706,
#   'show_id': 's3862',
#   'type': 'TV Show',
#   'title': 'Cupcake & Dino - General Services',
#   'director': 'None',
#   'country': 'Canada',
#   'date_added': Timestamp('2019-05-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y7',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV, TV Comedies"},
#  129: {'index': 2866,
#   'show_id': 's3867',
#   'type': 'Movie',
#   'title': 'The Last Summer',
#   'director': 'William Bindley',
#   'country': 'United States',
#   'date_added': Timestamp('2019-05-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '110 min',
#   'listed_in': 'Comedies, Romantic Movies'},
#  130: {'index': 7708,
#   'show_id': 's3868',
#   'type': 'TV Show',
#   'title': 'Tuca & Bertie',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-05-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies'},
#  131: {'index': 2863,
#   'show_id': 's3863',
#   'type': 'Movie',
#   'title': 'Despite Everything',
#   'director': 'Gabriela Tagliavini',
#   'country': 'Spain',
#   'date_added': Timestamp('2019-05-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '79 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies'},
#  132: {'index': 2860,
#   'show_id': 's3859',
#   'type': 'Movie',
#   'title': 'The Wandering Earth',
#   'director': 'Frant Gwo',
#   'country': 'China',
#   'date_added': Timestamp('2019-05-06 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '125 min',
#   'listed_in': 'International Movies, Sci-Fi & Fantasy'},
#  133: {'index': 2859,
#   'show_id': 's3858',
#   'type': 'Movie',
#   'title': 'Last Breath',
#   'director': 'Alex Parkinson, Richard da Costa',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2019-05-06 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '86 min',
#   'listed_in': 'Documentaries, International Movies'},
#  134: {'index': 7705,
#   'show_id': 's3856',
#   'type': 'TV Show',
#   'title': 'The Writer',
#   'director': 'None',
#   'country': 'Lebanon',
#   'date_added': Timestamp('2019-05-07 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  135: {'index': 380,
#   'show_id': 's3854',
#   'type': 'TV Show',
#   'title': 'I Have a Script',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-05-07 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Comedies, TV Dramas'},
#  136: {'index': 7704,
#   'show_id': 's3855',
#   'type': 'TV Show',
#   'title': 'In the Bosom of a Thorn',
#   'director': 'None',
#   'country': 'Kuwait',
#   'date_added': Timestamp('2019-05-07 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas'},
#  137: {'index': 7703,
#   'show_id': 's3853',
#   'type': 'TV Show',
#   'title': 'Abyss',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2019-05-07 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, Korean TV Shows'},
#  138: {'index': 386,
#   'show_id': 's3857',
#   'type': 'TV Show',
#   'title': 'What If?',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-05-07 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas'},
#  139: {'index': 2857,
#   'show_id': 's3842',
#   'type': 'Movie',
#   'title': 'Wine Country',
#   'director': 'Amy Poehler',
#   'country': 'United States',
#   'date_added': Timestamp('2019-05-10 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '104 min',
#   'listed_in': 'Comedies'},
#  140: {'index': 7684,
#   'show_id': 's3839',
#   'type': 'TV Show',
#   'title': 'The Mechanism',
#   'director': 'None',
#   'country': 'Brazil',
#   'date_added': Timestamp('2019-05-10 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  141: {'index': 7699,
#   'show_id': 's3836',
#   'type': 'TV Show',
#   'title': 'Easy',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-05-10 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'TV Comedies, TV Dramas'},
#  142: {'index': 7701,
#   'show_id': 's3838',
#   'type': 'TV Show',
#   'title': 'Jailbirds',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2019-05-10 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Reality TV'},
#  143: {'index': 7702,
#   'show_id': 's3841',
#   'type': 'TV Show',
#   'title': 'The Society',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-05-10 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Dramas, Teen TV Shows'},
#  144: {'index': 2854,
#   'show_id': 's3834',
#   'type': 'Movie',
#   'title': 'Shéhérazade',
#   'director': 'Jean-Bernard Marlin',
#   'country': 'France',
#   'date_added': Timestamp('2019-05-11 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '111 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies'},
#  145: {'index': 7698,
#   'show_id': 's3832',
#   'type': 'TV Show',
#   'title': 'The Defected',
#   'director': 'None',
#   'country': 'China',
#   'date_added': Timestamp('2019-05-12 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  146: {'index': 2851,
#   'show_id': 's3830',
#   'type': 'Movie',
#   'title': 'Malibu Rescue',
#   'director': 'Savage Steve Holland',
#   'country': 'United States',
#   'date_added': Timestamp('2019-05-13 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-G',
#   'duration': '70 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  147: {'index': 2849,
#   'show_id': 's3826',
#   'type': 'Movie',
#   'title': 'Backdraft 2',
#   'director': 'Gonzalo López-Gallego',
#   'country': 'United States',
#   'date_added': Timestamp('2019-05-14 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '102 min',
#   'listed_in': 'Action & Adventure, Dramas'},
#  148: {'index': 7697,
#   'show_id': 's3828',
#   'type': 'Movie',
#   'title': 'Still LAUGH-IN: The Stars Celebrate',
#   'director': 'None',
# ...
#  950: {'index': 1198,
#   'show_id': 's1254',
#   'type': 'Movie',
#   'title': 'LEGO Marvel Spider-Man: Vexed by Venom',
#   'director': 'Andrew Duncan, Ken Cunningham',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y',
#   'duration': '22 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  951: {'index': 1192,
#   'show_id': 's1247',
#   'type': 'TV Show',
#   'title': 'A Perfect Day For Arsenide',
#   'director': 'Sunny Lau',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-03-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Classic & Cult TV, Crime TV Shows, International TV Shows'},
#  952: {'index': 1099,
#   'show_id': 's1118',
#   'type': 'Movie',
#   'title': 'Ibrahim a Fate to Define',
#   'director': 'Lina Al Abed',
#   'country': 'Lebanon',
#   'date_added': Timestamp('2021-04-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '75 min',
#   'listed_in': 'Documentaries, International Movies'},
#  953: {'index': 1115,
#   'show_id': 's1138',
#   'type': 'Movie',
#   'title': 'The Knight and the Princess',
#   'director': 'Bashir El Deek',
#   'country': 'Egypt',
#   'date_added': Timestamp('2021-04-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '96 min',
#   'listed_in': 'Action & Adventure, International Movies, Music & Musicals'},
#  954: {'index': 1089,
#   'show_id': 's1107',
#   'type': 'Movie',
#   'title': 'Cross: Rise of the Villains',
#   'director': 'Patrick Durham, Paul G. Volk',
#   'country': 'United States',
#   'date_added': Timestamp('2021-04-02 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '100 min',
#   'listed_in': 'Action & Adventure'},
#  955: {'index': 1069,
#   'show_id': 's1075',
#   'type': 'Movie',
#   'title': 'Motu Patlu the Superheroes – Super Villains from Mars',
#   'director': 'Suhas Kadav',
#   'country': 'India',
#   'date_added': Timestamp('2021-04-13 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y7',
#   'duration': '79 min',
#   'listed_in': 'Children & Family Movies'},
#  956: {'index': 1077,
#   'show_id': 's1078',
#   'type': 'Movie',
#   'title': 'Shiva: Journey to Plunotaria',
#   'director': 'Suhas Kadav',
#   'country': 'India',
#   'date_added': Timestamp('2021-04-13 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y7',
#   'duration': '81 min',
#   'listed_in': 'Children & Family Movies'},
#  957: {'index': 6808,
#   'show_id': 's1066',
#   'type': 'TV Show',
#   'title': 'Slasher',
#   'director': 'None',
#   'country': 'Canada',
#   'date_added': Timestamp('2021-04-14 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'TV Horror, TV Mysteries, TV Thrillers'},
#  958: {'index': 6810,
#   'show_id': 's1069',
#   'type': 'TV Show',
#   'title': 'Unnatural Selection',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-04-14 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Science & Nature TV'},
#  959: {'index': 6806,
#   'show_id': 's1064',
#   'type': 'TV Show',
#   'title': 'Living with Yourself',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-04-14 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies, TV Dramas'},
#  960: {'index': 1053,
#   'show_id': 's1043',
#   'type': 'TV Show',
#   'title': 'Garth Brooks: The Road I’m On',
#   'director': 'Glenn Weiss',
#   'country': 'United States',
#   'date_added': Timestamp('2021-04-15 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries'},
#  961: {'index': 6798,
#   'show_id': 's1050',
#   'type': 'TV Show',
#   'title': 'Ricky Zoom',
#   'director': 'None',
#   'country': 'China',
#   'date_added': Timestamp('2021-04-15 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y',
#   'duration': '1 Season',
#   'listed_in': "British TV Shows, Kids' TV"},
#  962: {'index': 1054,
#   'show_id': 's1047',
#   'type': 'Movie',
#   'title': 'Only Mine',
#   'director': 'Michael Civille',
#   'country': 'United States',
#   'date_added': Timestamp('2021-04-15 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '88 min',
#   'listed_in': 'Thrillers'},
#  963: {'index': 6785,
#   'show_id': 's1015',
#   'type': 'TV Show',
#   'title': 'PJ Masks',
#   'director': 'None',
#   'country': 'France',
#   'date_added': Timestamp('2021-04-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y',
#   'duration': '3 Seasons',
#   'listed_in': "Kids' TV"},
#  964: {'index': 1027,
#   'show_id': 's1009',
#   'type': 'Movie',
#   'title': 'Motu Patlu VS Robo Kids',
#   'director': 'Suhas Kadav',
#   'country': 'India',
#   'date_added': Timestamp('2021-04-20 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y',
#   'duration': '84 min',
#   'listed_in': 'Children & Family Movies'},
#  965: {'index': 177,
#   'show_id': 's1011',
#   'type': 'Movie',
#   'title': 'Rudra: The Rise of King Pharaoh',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-04-20 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y7',
#   'duration': '91 min',
#   'listed_in': 'Children & Family Movies'},
#  966: {'index': 1001,
#   'show_id': 's988',
#   'type': 'Movie',
#   'title': 'Legal Hash',
#   'director': 'Rindala Kodeih',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-04-23 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '103 min',
#   'listed_in': 'Comedies, International Movies'},
#  967: {'index': 1000,
#   'show_id': 's975',
#   'type': 'Movie',
#   'title': 'Ram Prasad Ki Tehrvi',
#   'director': 'Seema Pahwa',
#   'country': 'India',
#   'date_added': Timestamp('2021-04-24 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '113 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies'},
#  968: {'index': 999,
#   'show_id': 's959',
#   'type': 'Movie',
#   'title': 'Seven',
#   'director': 'Tosin Igho',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-04-30 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '113 min',
#   'listed_in': 'Dramas, International Movies'},
#  969: {'index': 7,
#   'show_id': 's939',
#   'type': 'Movie',
#   'title': 'Motu Patlu in the Game of Zones',
#   'director': 'Suhas Kadav',
#   'country': 'India',
#   'date_added': Timestamp('2021-05-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y7',
#   'duration': '87 min',
#   'listed_in': 'Children & Family Movies, Comedies, Music & Musicals'},
#  970: {'index': 960,
#   'show_id': 's918',
#   'type': 'Movie',
#   'title': 'Framing John DeLorean',
#   'director': 'Don Argott, Sheena M. Joyce',
#   'country': 'United States',
#   'date_added': Timestamp('2021-05-05 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '109 min',
#   'listed_in': 'Documentaries, Dramas'},
#  971: {'index': 946,
#   'show_id': 's902',
#   'type': 'Movie',
#   'title': 'Deadly Switch',
#   'director': 'Svetlana Cvetko',
#   'country': 'United States',
#   'date_added': Timestamp('2021-05-10 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '86 min',
#   'listed_in': 'Independent Movies, Thrillers'},
#  972: {'index': 870,
#   'show_id': 's795',
#   'type': 'Movie',
#   'title': 'Gold Statue',
#   'director': 'Tade Ogidan',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-06-02 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '145 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  973: {'index': 6748,
#   'show_id': 's781',
#   'type': 'TV Show',
#   'title': "Ben & Holly's Little Kingdom",
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-06-02 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-Y',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV"},
#  974: {'index': 896,
#   'show_id': 's824',
#   'type': 'Movie',
#   'title': 'Then Came You',
#   'director': 'Peter Hutchings',
#   'country': 'United States',
#   'date_added': Timestamp('2021-06-02 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '97 min',
#   'listed_in': 'Comedies, Dramas, Independent Movies'},
#  975: {'index': 895,
#   'show_id': 's823',
#   'type': 'Movie',
#   'title': 'The Wind',
#   'director': 'Emma Tammi',
#   'country': 'United States',
#   'date_added': Timestamp('2021-06-02 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '88 min',
#   'listed_in': 'Horror Movies'},
#  976: {'index': 854,
#   'show_id': 's774',
#   'type': 'Movie',
#   'title': 'The Girl and the Gun',
#   'director': 'Rae Red',
#   'country': 'Philippines',
#   'date_added': Timestamp('2021-06-03 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '78 min',
#   'listed_in': 'Dramas, International Movies, Thrillers'},
#  977: {'index': 838,
#   'show_id': 's746',
#   'type': 'Movie',
#   'title': 'Until Midnight',
#   'director': 'Tariq Alkazim',
#   'country': 'United Arab Emirates',
#   'date_added': Timestamp('2021-06-10 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '77 min',
#   'listed_in': 'International Movies, Thrillers'},
#  978: {'index': 814,
#   'show_id': 's706',
#   'type': 'Movie',
#   'title': 'Biking Borders',
#   'director': 'Max Jabs',
#   'country': 'Germany',
#   'date_added': Timestamp('2021-06-16 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '89 min',
#   'listed_in': 'Documentaries, International Movies, Sports Movies'},
#  979: {'index': 802,
#   'show_id': 's695',
#   'type': 'Movie',
#   'title': 'Aziza',
#   'director': 'Soudade Kaadan',
#   'country': 'Lebanon',
#   'date_added': Timestamp('2021-06-17 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '13 min',
#   'listed_in': 'Comedies, Dramas, Independent Movies'},
#  980: {'index': 811,
#   'show_id': 's702',
#   'type': 'Movie',
#   'title': 'Red Snow',
#   'director': 'Marie Clements',
#   'country': 'Canada',
#   'date_added': Timestamp('2021-06-17 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '96 min',
#   'listed_in': 'Dramas'},
#  981: {'index': 6719,
#   'show_id': 's674',
#   'type': 'TV Show',
#   'title': 'No Time for Shame',
#   'director': 'None',
#   'country': 'Argentina',
#   'date_added': Timestamp('2021-06-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV, Spanish-Language TV Shows'},
#  982: {'index': 141,
#   'show_id': 's664',
#   'type': 'TV Show',
#   'title': 'Charité at War',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-06-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas'},
#  983: {'index': 6721,
#   'show_id': 's675',
#   'type': 'TV Show',
#   'title': 'Pose',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-06-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'TV Dramas'},
#  984: {'index': 792,
#   'show_id': 's677',
#   'type': 'TV Show',
#   'title': 'Riverdale',
#   'director': 'Rob Seidenglanz',
#   'country': 'United States',
#   'date_added': Timestamp('2021-06-19 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '4 Seasons',
#   'listed_in': 'Crime TV Shows, TV Dramas, TV Mysteries'},
#  985: {'index': 790,
#   'show_id': 's650',
#   'type': 'Movie',
#   'title': 'Broken',
#   'director': 'Anurin Nwunembom',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-06-22 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '108 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  986: {'index': 776,
#   'show_id': 's635',
#   'type': 'Movie',
#   'title': 'Wonder Boy',
#   'director': 'Anissa Bonnefont',
#   'country': 'France',
#   'date_added': Timestamp('2021-06-26 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '83 min',
#   'listed_in': 'Documentaries, International Movies'},
#  987: {'index': 773,
#   'show_id': 's633',
#   'type': 'Movie',
#   'title': 'Wanted',
#   'director': 'Nibal Arakji',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-06-28 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '90 min',
#   'listed_in': 'Comedies, International Movies'},
#  988: {'index': 6701,
#   'show_id': 's621',
#   'type': 'TV Show',
#   'title': "Droppin' Cash: Los Angeles",
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-06-30 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV'},
#  989: {'index': 767,
#   'show_id': 's623',
#   'type': 'Movie',
#   'title': 'Lying and Stealing',
#   'director': 'Matt Aselton',
#   'country': 'United States',
#   'date_added': Timestamp('2021-06-30 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '100 min',
#   'listed_in': 'Thrillers'},
#  990: {'index': 744,
#   'show_id': 's597',
#   'type': 'Movie',
#   'title': 'Sword of Trust',
#   'director': 'Lynn Shelton',
#   'country': 'United States',
#   'date_added': Timestamp('2021-07-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '89 min',
#   'listed_in': 'Comedies, Dramas, Independent Movies'},
#  991: {'index': 747,
#   'show_id': 's600',
#   'type': 'Movie',
#   'title': 'The Best of Enemies',
#   'director': 'Robin Bissell',
#   'country': 'United States',
#   'date_added': Timestamp('2021-07-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'PG-13',
#   'duration': '133 min',
#   'listed_in': 'Dramas'},
#  992: {'index': 738,
#   'show_id': 's590',
#   'type': 'Movie',
#   'title': 'Red Joan',
#   'director': 'Trevor Nunn',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-07-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '101 min',
#   'listed_in': 'Dramas, International Movies'},
#  993: {'index': 720,
#   'show_id': 's570',
#   'type': 'Movie',
#   'title': 'Dreamy Eyes',
#   'director': 'Victor Vu',
#   'country': 'Vietnam',
#   'date_added': Timestamp('2021-07-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '117 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  994: {'index': 722,
#   'show_id': 's573',
#   'type': 'Movie',
#   'title': 'Hampstead',
#   'director': 'Joel Hopkins',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-07-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'PG-13',
#   'duration': '103 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  995: {'index': 726,
#   'show_id': 's577',
#   'type': 'Movie',
#   'title': 'Mary Magdalene',
#   'director': 'Garth Davis',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-07-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '120 min',
#   'listed_in': 'Dramas, Faith & Spirituality, International Movies'},
#  996: {'index': 764,
#   'show_id': 's617',
#   'type': 'Movie',
#   'title': 'Working Title',
#   'director': 'Mary Harron',
#   'country': 'United States',
#   'date_added': Timestamp('2021-07-01 00:00:00'),
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '110 min',
#   'listed_in': 'Dramas'},
#  997: {'index': 6698,
#   'show_id': 's554',
#   'type': 'TV Show',
#   'title': 'Mortel',
#   'director': 'None',
#   'country': 'France',
#   'date_added': Timestamp('2021-07-02 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  998: {'index': 699,
#   'show_id': 's535',
#   'type': 'Movie',
#   'title': 'Si Doel the Movie 2',
#   'director': 'Rano Karno',
#   'country': 'Indonesia',
#   'date_added': Timestamp('2021-07-06 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-G',
#   'duration': '95 min',
#   'listed_in': 'Dramas, International Movies'},
#  999: {'index': 6685,
#   'show_id': 's533',
#   'type': 'TV Show',
#   'title': 'Scream',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-07-06 00:00:00'),
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'Crime TV Shows, TV Horror, TV Mysteries'},
#  ...}

# %%
#Dicionario correspondiente al DataFrame "mask20" 
dic20=mask20.reset_index().to_dict(orient="index")
dic20
# Out:
# {0: {'index': 7537,
#   'show_id': 's3434',
#   'type': 'TV Show',
#   'title': 'The Hook Up Plan',
#   'director': 'None',
#   'country': 'France',
#   'date_added': Timestamp('2019-10-11 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Comedies'},
#  1: {'index': 7517,
#   'show_id': 's3370',
#   'type': 'TV Show',
#   'title': 'BoJack Horseman',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-10-25 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '6 Seasons',
#   'listed_in': 'TV Comedies'},
#  2: {'index': 7484,
#   'show_id': 's3288',
#   'type': 'TV Show',
#   'title': 'Maradona in Mexico',
#   'director': 'None',
#   'country': 'Argentina',
#   'date_added': Timestamp('2019-11-13 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Spanish-Language TV Shows'},
#  3: {'index': 7436,
#   'show_id': 's3169',
#   'type': 'TV Show',
#   'title': 'Fuller House',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2019-12-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '5 Seasons',
#   'listed_in': 'TV Comedies'},
#  4: {'index': 7412,
#   'show_id': 's3076',
#   'type': 'TV Show',
#   'title': 'Spinning Out',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Dramas'},
#  5: {'index': 2404,
#   'show_id': 's3068',
#   'type': 'TV Show',
#   'title': 'Nisman: The Prosecutor, the President, and the Spy',
#   'director': 'Justin Webster',
#   'country': 'Spain',
#   'date_added': Timestamp('2020-01-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries, International TV Shows'},
#  6: {'index': 2399,
#   'show_id': 's3061',
#   'type': 'Movie',
#   'title': 'Ghost Stories',
#   'director': 'Anurag Kashyap, Dibakar Banerjee, Karan Johar, Zoya Akhtar',
#   'country': 'India',
#   'date_added': Timestamp('2020-01-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '145 min',
#   'listed_in': 'Horror Movies, International Movies, Thrillers'},
#  7: {'index': 7408,
#   'show_id': 's3066',
#   'type': 'TV Show',
#   'title': 'Messiah',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Dramas, TV Thrillers'},
#  8: {'index': 7401,
#   'show_id': 's3050',
#   'type': 'TV Show',
#   'title': 'Sex, Explained',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-02 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Science & Nature TV'},
#  9: {'index': 2392,
#   'show_id': 's3047',
#   'type': 'Movie',
#   'title': 'All the Freckles in the World',
#   'director': 'Yibrán Asuad',
#   'country': 'Mexico',
#   'date_added': Timestamp('2020-01-03 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '90 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies'},
#  10: {'index': 7399,
#   'show_id': 's3046',
#   'type': 'TV Show',
#   'title': 'Dracula',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2020-01-04 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, International TV Shows, TV Dramas'},
#  11: {'index': 2391,
#   'show_id': 's3045',
#   'type': 'Movie',
#   'title': 'Live Twice, Love Once',
#   'director': 'Maria Ripoll',
#   'country': 'Spain',
#   'date_added': Timestamp('2020-01-07 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '102 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  12: {'index': 6012,
#   'show_id': 's3043',
#   'type': 'TV Show',
#   'title': 'Cheer',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-08 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Reality TV, Teen TV Shows'},
#  13: {'index': 2389,
#   'show_id': 's3042',
#   'type': 'Movie',
#   'title': 'Bulletproof 2',
#   'director': 'Don Michael Paul',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-09 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '97 min',
#   'listed_in': 'Action & Adventure, Comedies'},
#  14: {'index': 7396,
#   'show_id': 's3038',
#   'type': 'TV Show',
#   'title': 'Medical Police',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-10 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, TV Action & Adventure, TV Comedies'},
#  15: {'index': 7395,
#   'show_id': 's3036',
#   'type': 'TV Show',
#   'title': 'Harvey Street Kids',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-10 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y7',
#   'duration': '4 Seasons',
#   'listed_in': "Kids' TV, TV Comedies"},
#  16: {'index': 7393,
#   'show_id': 's3034',
#   'type': 'TV Show',
#   'title': 'AJ and the Queen',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-10 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies, TV Dramas'},
#  17: {'index': 2387,
#   'show_id': 's3037',
#   'type': 'TV Show',
#   'title': 'Jamtara - Sabka Number Ayega',
#   'director': 'Soumendra Padhi',
#   'country': 'India',
#   'date_added': Timestamp('2020-01-10 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  18: {'index': 7397,
#   'show_id': 's3040',
#   'type': 'TV Show',
#   'title': 'The InBESTigators',
#   'director': 'None',
#   'country': 'Australia',
#   'date_added': Timestamp('2020-01-10 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV, TV Comedies"},
#  19: {'index': 7398,
#   'show_id': 's3041',
#   'type': 'TV Show',
#   'title': 'Until Dawn',
#   'director': 'None',
#   'country': 'France',
#   'date_added': Timestamp('2020-01-10 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV, TV Comedies'},
#  20: {'index': 7406,
#   'show_id': 's3031',
#   'type': 'TV Show',
#   'title': 'The Healing Powers of Dude',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-01-13 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-G',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV, TV Comedies, TV Dramas"},
#  21: {'index': 2383,
#   'show_id': 's3028',
#   'type': 'Movie',
#   'title': 'Leslie Jones: Time Machine',
#   'director': 'David Benioff, D.B. Weiss',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-14 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '66 min',
#   'listed_in': 'Stand-Up Comedy'},
#  22: {'index': 7391,
#   'show_id': 's3025',
#   'type': 'TV Show',
#   'title': 'Killer Inside: The Mind of Aaron Hernandez',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-15 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  23: {'index': 7389,
#   'show_id': 's3016',
#   'type': 'TV Show',
#   'title': 'Handsome Siblings',
#   'director': 'None',
#   'country': 'China',
#   'date_added': Timestamp('2020-01-16 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas, TV Sci-Fi & Fantasy'},
#  24: {'index': 2372,
#   'show_id': 's3010',
#   'type': 'Movie',
#   'title': 'A Fall from Grace',
#   'director': 'Tyler Perry',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-17 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '121 min',
#   'listed_in': 'Dramas, Thrillers'},
#  25: {'index': 7388,
#   'show_id': 's3011',
#   'type': 'TV Show',
#   'title': 'Ares',
#   'director': 'None',
#   'country': 'Netherlands',
#   'date_added': Timestamp('2020-01-17 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas, TV Horror'},
#  26: {'index': 7283,
#   'show_id': 's3012',
#   'type': 'TV Show',
#   'title': 'Hip-Hop Evolution',
#   'director': 'None',
#   'country': 'Canada',
#   'date_added': Timestamp('2020-01-17 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '4 Seasons',
#   'listed_in': 'Docuseries, International TV Shows'},
#  27: {'index': 7302,
#   'show_id': 's3013',
#   'type': 'TV Show',
#   'title': 'Nailed It! Germany',
#   'director': 'None',
#   'country': 'Germany',
#   'date_added': Timestamp('2020-01-17 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV'},
#  28: {'index': 2370,
#   'show_id': 's3008',
#   'type': 'Movie',
#   'title': 'WHAT DID JACK DO?',
#   'director': 'David Lynch',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '17 min',
#   'listed_in': 'Dramas, Independent Movies'},
#  29: {'index': 2367,
#   'show_id': 's3004',
#   'type': 'Movie',
#   'title': 'Fortune Feimster: Sweet & Salty',
#   'director': 'Krysia Plonka',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-21 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '61 min',
#   'listed_in': 'Stand-Up Comedy'},
#  30: {'index': 7385,
#   'show_id': 's3001',
#   'type': 'TV Show',
#   'title': 'Pandemic: How to Prevent an Outbreak',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-22 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Science & Nature TV'},
#  31: {'index': 7384,
#   'show_id': 's2999',
#   'type': 'TV Show',
#   'title': '\u200bSAINT SEIYA: Knights of the Zodiac',
#   'director': 'None',
#   'country': 'Japan',
#   'date_added': Timestamp('2020-01-23 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '2 Seasons',
#   'listed_in': 'Anime Series, International TV Shows'},
#  32: {'index': 2365,
#   'show_id': 's3000',
#   'type': 'TV Show',
#   'title': 'The Ghost Bride',
#   'director': 'Quek Shio-chuan',
#   'country': 'Taiwan',
#   'date_added': Timestamp('2020-01-23 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas, TV Mysteries'},
#  33: {'index': 2364,
#   'show_id': 's2997',
#   'type': 'Movie',
#   'title': 'Alex Fernández: The Best Comedian in the World',
#   'director': 'Alex Díaz',
#   'country': 'Mexico',
#   'date_added': Timestamp('2020-01-23 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '51 min',
#   'listed_in': 'Stand-Up Comedy'},
#  34: {'index': 2363,
#   'show_id': 's2996',
#   'type': 'Movie',
#   'title': 'Airplane Mode',
#   'director': 'César Rodrigues',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-23 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '97 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies'},
#  35: {'index': 7383,
#   'show_id': 's2998',
#   'type': 'TV Show',
#   'title': 'October Faction',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-23 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Action & Adventure, TV Dramas, TV Horror'},
#  36: {'index': 7382,
#   'show_id': 's2995',
#   'type': 'TV Show',
#   'title': 'The Ranch',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-24 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '8 Seasons',
#   'listed_in': 'TV Comedies, TV Dramas'},
#  37: {'index': 305,
#   'show_id': 's2992',
#   'type': 'TV Show',
#   'title': 'Rise of Empires: Ottoman',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-01-24 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries'},
#  38: {'index': 7381,
#   'show_id': 's2994',
#   'type': 'TV Show',
#   'title': 'The goop lab with Gwyneth Paltrow',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-24 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV'},
#  39: {'index': 2359,
#   'show_id': 's2988',
#   'type': 'Movie',
#   'title': 'Vir Das: For India',
#   'director': 'Vir Das, Ajay Bhuyan',
#   'country': 'India',
#   'date_added': Timestamp('2020-01-26 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '76 min',
#   'listed_in': 'Stand-Up Comedy'},
#  40: {'index': 2357,
#   'show_id': 's2986',
#   'type': 'Movie',
#   'title': 'Shimla Mirchi',
#   'director': 'Ramesh Sippy',
#   'country': 'India',
#   'date_added': Timestamp('2020-01-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '121 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies'},
#  41: {'index': 7379,
#   'show_id': 's2985',
#   'type': 'TV Show',
#   'title': 'Omniscient',
#   'director': 'None',
#   'country': 'Brazil',
#   'date_added': Timestamp('2020-01-29 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas, TV Sci-Fi & Fantasy'},
#  42: {'index': 7378,
#   'show_id': 's2984',
#   'type': 'TV Show',
#   'title': 'Night on Earth',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2020-01-29 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Science & Nature TV'},
#  43: {'index': 239,
#   'show_id': 's2983',
#   'type': 'TV Show',
#   'title': 'Find Yourself',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-01-29 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Comedies'},
#  44: {'index': 7377,
#   'show_id': 's2981',
#   'type': 'TV Show',
#   'title': 'What the Love! with Karan Johar',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-30 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV, Romantic TV Shows'},
#  45: {'index': 7376,
#   'show_id': 's2980',
#   'type': 'TV Show',
#   'title': 'THE STRANGER',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2020-01-30 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, Crime TV Shows, International TV Shows'},
#  46: {'index': 2351,
#   'show_id': 's2971',
#   'type': 'Movie',
#   'title': '37 Seconds',
#   'director': 'Hikari',
#   'country': 'Japan',
#   'date_added': Timestamp('2020-01-31 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '116 min',
#   'listed_in': 'Dramas, International Movies'},
#  47: {'index': 7374,
#   'show_id': 's2977',
#   'type': 'TV Show',
#   'title': 'Unauthorized Living',
#   'director': 'None',
#   'country': 'Spain',
#   'date_added': Timestamp('2020-01-31 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Crime TV Shows, International TV Shows, Spanish-Language TV Shows'},
#  48: {'index': 2354,
#   'show_id': 's2976',
#   'type': 'Movie',
#   'title': 'Miss Americana',
#   'director': 'Lana Wilson',
#   'country': 'United States',
#   'date_added': Timestamp('2020-01-31 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '85 min',
#   'listed_in': 'Documentaries, Music & Musicals'},
#  49: {'index': 7372,
#   'show_id': 's2972',
#   'type': 'TV Show',
#   'title': 'Diablero',
#   'director': 'None',
#   'country': 'Mexico',
#   'date_added': Timestamp('2020-01-31 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'International TV Shows, Spanish-Language TV Shows, TV Action & Adventure'},
#  50: {'index': 7373,
#   'show_id': 's2975',
#   'type': 'TV Show',
#   'title': 'Luna Nera',
#   'director': 'None',
#   'country': 'Italy',
#   'date_added': Timestamp('2020-01-31 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Dramas'},
#  51: {'index': 7366,
#   'show_id': 's2960',
#   'type': 'TV Show',
#   'title': 'Itaewon Class',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2020-02-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Korean TV Shows, TV Dramas'},
#  52: {'index': 7367,
#   'show_id': 's2965',
#   'type': 'Movie',
#   'title': 'Night on Earth: Shot in the Dark',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2020-02-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '59 min',
#   'listed_in': 'Movies'},
#  53: {'index': 2342,
#   'show_id': 's2956',
#   'type': 'Movie',
#   'title': 'The Silent War',
#   'director': 'Alfonso Cortés-Cavanillas',
#   'country': 'Spain',
#   'date_added': Timestamp('2020-02-03 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '122 min',
#   'listed_in': 'Dramas, International Movies, Thrillers'},
#  54: {'index': 7364,
#   'show_id': 's2954',
#   'type': 'TV Show',
#   'title': 'Team Kaylie',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-03 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '3 Seasons',
#   'listed_in': "Kids' TV, TV Comedies"},
#  55: {'index': 2338,
#   'show_id': 's2951',
#   'type': 'Movie',
#   'title': 'Dragonheart: Vengeance',
#   'director': 'Ivan Silvestrini',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-04 00:00:00'),
#   'release_year': 2020,
#   'rating': 'PG-13',
#   'duration': '97 min',
#   'listed_in': 'Action & Adventure, Sci-Fi & Fantasy'},
#  56: {'index': 2340,
#   'show_id': 's2953',
#   'type': 'Movie',
#   'title': "Tom Papa: You're Doing Great!",
#   'director': 'Gregory Jacobs',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-04 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '60 min',
#   'listed_in': 'Stand-Up Comedy'},
#  57: {'index': 4168,
#   'show_id': 's5973',
#   'type': 'Movie',
#   'title': '#cats_the_mewvie',
#   'director': 'Michael Margolis',
#   'country': 'Canada',
#   'date_added': Timestamp('2020-02-05 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '90 min',
#   'listed_in': 'Documentaries, International Movies'},
#  58: {'index': 2336,
#   'show_id': 's2949',
#   'type': 'TV Show',
#   'title': 'The Pharmacist',
#   'director': 'Julia Willoughby Nason, Jenner Furst',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-05 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  59: {'index': 2337,
#   'show_id': 's2950',
#   'type': 'Movie',
#   'title': 'Uppity: The Willy T. Ribbs Story',
#   'director': 'Nate Adams, Adam Carolla',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-05 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '106 min',
#   'listed_in': 'Documentaries, Sports Movies'},
#  60: {'index': 7363,
#   'show_id': 's2946',
#   'type': 'TV Show',
#   'title': 'Cagaster of an Insect Cage',
#   'director': 'None',
#   'country': 'Japan',
#   'date_added': Timestamp('2020-02-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Anime Series, International TV Shows'},
#  61: {'index': 7360,
#   'show_id': 's2938',
#   'type': 'TV Show',
#   'title': 'Dragons: Rescue Riders',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-07 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV, TV Comedies"},
#  62: {'index': 304,
#   'show_id': 's2943',
#   'type': 'TV Show',
#   'title': 'My Holo Love',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-02-07 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Korean TV Shows, Romantic TV Shows'},
#  63: {'index': 2332,
#   'show_id': 's2940',
#   'type': 'Movie',
#   'title': 'Horse Girl',
#   'director': 'Jeff Baena',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-07 00:00:00'),
#   'release_year': 2020,
#   'rating': 'R',
#   'duration': '104 min',
#   'listed_in': 'Dramas, Independent Movies'},
#  64: {'index': 7362,
#   'show_id': 's2942',
#   'type': 'TV Show',
#   'title': 'Locke & Key',
#   'director': 'None',
#   'country': 'Canada',
#   'date_added': Timestamp('2020-02-07 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'TV Action & Adventure, TV Dramas, TV Mysteries'},
#  65: {'index': 7017,
#   'show_id': 's2945',
#   'type': 'TV Show',
#   'title': 'Who Killed Malcolm X?',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-07 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  66: {'index': 2325,
#   'show_id': 's2930',
#   'type': 'Movie',
#   'title': 'ROAD TO ROMA',
#   'director': 'Andres Clariond',
#   'country': 'Mexico',
#   'date_added': Timestamp('2020-02-11 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '73 min',
#   'listed_in': 'Documentaries, International Movies'},
#  67: {'index': 7358,
#   'show_id': 's2928',
#   'type': 'Movie',
#   'title': 'Captain Underpants Epic Choice-o-Rama',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-11 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y7',
#   'duration': '81 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  68: {'index': 2323,
#   'show_id': 's2926',
#   'type': 'Movie',
#   'title': 'To All the Boys: P.S. I Still Love You',
#   'director': 'Michael Fimognari',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-12 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '102 min',
#   'listed_in': 'Comedies, Romantic Movies'},
#  69: {'index': 7356,
#   'show_id': 's2922',
#   'type': 'TV Show',
#   'title': 'Narcos: Mexico',
#   'director': 'None',
#   'country': 'Mexico',
#   'date_added': Timestamp('2020-02-13 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Crime TV Shows, TV Action & Adventure, TV Dramas'},
#  70: {'index': 7354,
#   'show_id': 's2918',
#   'type': 'TV Show',
#   'title': 'Taj Mahal 1989',
#   'director': 'None',
#   'country': 'India',
#   'date_added': Timestamp('2020-02-14 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Comedies'},
#  71: {'index': 2316,
#   'show_id': 's2915',
#   'type': 'Movie',
#   'title': 'Isi & Ossi',
#   'director': 'Oliver Kienle',
#   'country': 'Germany',
#   'date_added': Timestamp('2020-02-14 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '113 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies'},
#  72: {'index': 7350,
#   'show_id': 's2901',
#   'type': 'TV Show',
#   'title': 'Spectros',
#   'director': 'None',
#   'country': 'Brazil',
#   'date_added': Timestamp('2020-02-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Horror, TV Mysteries'},
#  73: {'index': 302,
#   'show_id': 's2894',
#   'type': 'TV Show',
#   'title': 'Passion. Panache. Pep',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-02-21 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-G',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV'},
#  74: {'index': 2302,
#   'show_id': 's2898',
#   'type': 'Movie',
#   'title': 'The Last Thing He Wanted',
#   'director': 'Dee Rees',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-21 00:00:00'),
#   'release_year': 2020,
#   'rating': 'R',
#   'duration': '116 min',
#   'listed_in': 'Dramas, Thrillers'},
#  75: {'index': 7348,
#   'show_id': 's2893',
#   'type': 'TV Show',
#   'title': 'Hyena',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2020-02-21 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Korean TV Shows, Romantic TV Shows'},
#  76: {'index': 7347,
#   'show_id': 's2892',
#   'type': 'TV Show',
#   'title': 'Gentefied',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-21 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies, TV Dramas'},
#  77: {'index': 7349,
#   'show_id': 's2895',
#   'type': 'TV Show',
#   'title': 'Puerta 7',
#   'director': 'None',
#   'country': 'Argentina',
#   'date_added': Timestamp('2020-02-21 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, Spanish-Language TV Shows'},
#  78: {'index': 2300,
#   'show_id': 's2896',
#   'type': 'Movie',
#   'title': 'System Crasher',
#   'director': 'Nora Fingscheidt',
#   'country': 'Germany',
#   'date_added': Timestamp('2020-02-21 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '120 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies'},
#  79: {'index': 2303,
#   'show_id': 's2899',
#   'type': 'Movie',
#   'title': 'Yeh Ballet',
#   'director': 'Sooni Taraporevala',
#   'country': 'India',
#   'date_added': Timestamp('2020-02-21 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '117 min',
#   'listed_in': 'Dramas, International Movies'},
#  80: {'index': 7346,
#   'show_id': 's2889',
#   'type': 'TV Show',
#   'title': 'Hi Bye, Mama!',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2020-02-23 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Korean TV Shows, Romantic TV Shows'},
#  81: {'index': 2296,
#   'show_id': 's2887',
#   'type': 'Movie',
#   'title': 'Pete Davidson: Alive From New York',
#   'director': 'Jason Orley',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-25 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '50 min',
#   'listed_in': 'Stand-Up Comedy'},
#  82: {'index': 7345,
#   'show_id': 's2884',
#   'type': 'TV Show',
#   'title': 'The Trials of Gabriel Fernandez',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-26 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  83: {'index': 7344,
#   'show_id': 's2881',
#   'type': 'TV Show',
#   'title': 'I Am Not Okay With This',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-26 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies, TV Dramas, TV Sci-Fi & Fantasy'},
#  84: {'index': 2290,
#   'show_id': 's2878',
#   'type': 'TV Show',
#   'title': 'Six Windows in the Desert',
#   'director': 'Ali Kalthami, Meshal Aljaser, Faris Godus, Mohamed al Salman, Faisal al Amer',
#   'country': 'Saudi Arabia',
#   'date_added': Timestamp('2020-02-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'TV Shows'},
#  85: {'index': 7343,
#   'show_id': 's2876',
#   'type': 'TV Show',
#   'title': 'Followers',
#   'director': 'None',
#   'country': 'Japan',
#   'date_added': Timestamp('2020-02-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas'},
#  86: {'index': 7342,
#   'show_id': 's2875',
#   'type': 'TV Show',
#   'title': 'Altered Carbon',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Crime TV Shows, TV Action & Adventure, TV Dramas'},
#  87: {'index': 2288,
#   'show_id': 's2874',
#   'type': 'Movie',
#   'title': 'Ala Vaikunthapurramuloo',
#   'director': 'Trivikram Srinivas',
#   'country': 'India',
#   'date_added': Timestamp('2020-02-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '162 min',
#   'listed_in': 'Action & Adventure, Comedies, Dramas'},
#  88: {'index': 2285,
#   'show_id': 's2868',
#   'type': 'Movie',
#   'title': 'All The Bright Places',
#   'director': 'Brett Haley',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-28 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '109 min',
#   'listed_in': 'Dramas, Romantic Movies'},
#  89: {'index': 7339,
#   'show_id': 's2871',
#   'type': 'TV Show',
#   'title': 'Queen Sono',
#   'director': 'None',
#   'country': 'South Africa',
#   'date_added': Timestamp('2020-02-28 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Action & Adventure, TV Dramas'},
#  90: {'index': 7341,
#   'show_id': 's2873',
#   'type': 'TV Show',
#   'title': 'Unstoppable',
#   'director': 'None',
#   'country': 'Mexico',
#   'date_added': Timestamp('2020-02-28 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Spanish-Language TV Shows, TV Dramas'},
#  91: {'index': 7336,
#   'show_id': 's2856',
#   'type': 'TV Show',
#   'title': 'Babylon Berlin',
#   'director': 'None',
#   'country': 'Germany',
#   'date_added': Timestamp('2020-03-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  92: {'index': 301,
#   'show_id': 's2858',
#   'type': 'TV Show',
#   'title': 'Calico Critters Mini Episodes Clover',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-03-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV"},
#  93: {'index': 2277,
#   'show_id': 's2865',
#   'type': 'Movie',
#   'title': 'Velvet Colección: Grand Finale',
#   'director': 'Gustavo Ron',
#   'country': 'Not Given',
#   'date_added': Timestamp('2020-03-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '82 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  94: {'index': 2274,
#   'show_id': 's2854',
#   'type': 'Movie',
#   'title': 'Fat Ballerina - David A. Arnold',
#   'director': 'Milton Horowitz',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-02 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '61 min',
#   'listed_in': 'Stand-Up Comedy'},
#  95: {'index': 2270,
#   'show_id': 's2850',
#   'type': 'Movie',
#   'title': 'Taylor Tomlinson: Quarter-Life Crisis',
#   'director': 'Marcus Raboy',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-03 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '61 min',
#   'listed_in': 'Stand-Up Comedy'},
#  96: {'index': 7334,
#   'show_id': 's2842',
#   'type': 'TV Show',
#   'title': 'Mighty Little Bheem: Festival of Colors',
#   'director': 'None',
#   'country': 'India',
#   'date_added': Timestamp('2020-03-05 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV, TV Comedies"},
#  97: {'index': 2260,
#   'show_id': 's2841',
#   'type': 'Movie',
#   'title': 'Angu Vaikuntapurathu (Malayalam)',
#   'director': 'Trivikram Srinivas',
#   'country': 'India',
#   'date_added': Timestamp('2020-03-05 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '162 min',
#   'listed_in': 'Action & Adventure, Comedies, Dramas'},
#  98: {'index': 7333,
#   'show_id': 's2839',
#   'type': 'TV Show',
#   'title': 'Ugly Delicious',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Docuseries'},
#  99: {'index': 2255,
#   'show_id': 's2834',
#   'type': 'Movie',
#   'title': 'Guilty',
#   'director': 'Ruchi Narain',
#   'country': 'India',
#   'date_added': Timestamp('2020-03-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '120 min',
#   'listed_in': 'Dramas, International Movies'},
#  100: {'index': 2258,
#   'show_id': 's2837',
#   'type': 'Movie',
#   'title': 'Spenser Confidential',
#   'director': 'Peter Berg',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'R',
#   'duration': '111 min',
#   'listed_in': 'Action & Adventure, Comedies'},
#  101: {'index': 2259,
#   'show_id': 's2838',
#   'type': 'Movie',
#   'title': 'Twin Murders: the Silence of the White City',
#   'director': 'Daniel Calparsoro',
#   'country': 'Spain',
#   'date_added': Timestamp('2020-03-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '110 min',
#   'listed_in': 'International Movies, Thrillers'},
#  102: {'index': 2253,
#   'show_id': 's2831',
#   'type': 'Movie',
#   'title': 'Sitara: Let Girls Dream',
#   'director': 'Sharmeen Obaid-Chinoy',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-03-08 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '16 min',
#   'listed_in': 'Children & Family Movies, Dramas'},
#  103: {'index': 2251,
#   'show_id': 's2829',
#   'type': 'Movie',
#   'title': 'Carmen Sandiego: To Steal or Not to Steal',
#   'director': 'Jos Humphrey',
#   'country': 'Canada',
#   'date_added': Timestamp('2020-03-10 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y7',
#   'duration': '82 min',
#   'listed_in': 'Children & Family Movies'},
#  104: {'index': 2252,
#   'show_id': 's2830',
#   'type': 'Movie',
#   'title': 'Marc Maron: End Times Fun',
#   'director': 'Lynn Shelton',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-10 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '71 min',
#   'listed_in': 'Stand-Up Comedy'},
#  105: {'index': 7332,
#   'show_id': 's2828',
#   'type': 'TV Show',
#   'title': 'The Circle Brazil',
#   'director': 'None',
#   'country': 'Brazil',
#   'date_added': Timestamp('2020-03-11 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV'},
#  106: {'index': 7330,
#   'show_id': 's2826',
#   'type': 'TV Show',
#   'title': 'Dirty Money',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-11 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  107: {'index': 7331,
#   'show_id': 's2827',
#   'type': 'TV Show',
#   'title': 'On My Block',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-11 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '3 Seasons',
#   'listed_in': 'Romantic TV Shows, TV Comedies, TV Dramas'},
#  108: {'index': 2247,
#   'show_id': 's2822',
#   'type': 'TV Show',
#   'title': 'Kingdom',
#   'director': 'Kim Seong-hun',
#   'country': 'South Korea',
#   'date_added': Timestamp('2020-03-13 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'International TV Shows, Korean TV Shows, TV Action & Adventure'},
#  109: {'index': 2245,
#   'show_id': 's2820',
#   'type': 'Movie',
#   'title': 'Go Karts',
#   'director': 'Owen Trevor',
#   'country': 'Australia',
#   'date_added': Timestamp('2020-03-13 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '103 min',
#   'listed_in': 'Children & Family Movies, Dramas'},
#  110: {'index': 2248,
#   'show_id': 's2823',
#   'type': 'Movie',
#   'title': 'Lost Girls',
#   'director': 'Liz Garbus',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-13 00:00:00'),
#   'release_year': 2020,
#   'rating': 'R',
#   'duration': '95 min',
#   'listed_in': 'Dramas'},
#  111: {'index': 7329,
#   'show_id': 's2825',
#   'type': 'TV Show',
#   'title': 'The Valhalla Murders',
#   'director': 'None',
#   'country': 'Iceland',
#   'date_added': Timestamp('2020-03-13 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  112: {'index': 7328,
#   'show_id': 's2819',
#   'type': 'TV Show',
#   'title': 'Bloodride',
#   'director': 'None',
#   'country': 'Norway',
#   'date_added': Timestamp('2020-03-13 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Horror, TV Mysteries'},
#  113: {'index': 7327,
#   'show_id': 's2817',
#   'type': 'TV Show',
#   'title': '100 Humans',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-13 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Science & Nature TV'},
#  114: {'index': 2241,
#   'show_id': 's2816',
#   'type': 'Movie',
#   'title': 'Jai Mummy Di',
#   'director': 'Navjot Gulati',
#   'country': 'India',
#   'date_added': Timestamp('2020-03-14 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '101 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies'},
#  115: {'index': 7325,
#   'show_id': 's2808',
#   'type': 'TV Show',
#   'title': 'Shaun the Sheep: Adventures from Mossy Bottom',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2020-03-17 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y7',
#   'duration': '1 Season',
#   'listed_in': "British TV Shows, Kids' TV, TV Comedies"},
#  116: {'index': 2238,
#   'show_id': 's2807',
#   'type': 'Movie',
#   'title': 'Bert Kreischer: Hey Big Boy',
#   'director': 'Jeff Tomsic',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-17 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '62 min',
#   'listed_in': 'Stand-Up Comedy'},
#  117: {'index': 7323,
#   'show_id': 's2803',
#   'type': 'TV Show',
#   'title': 'Caliphate',
#   'director': 'None',
#   'country': 'Sweden',
#   'date_added': Timestamp('2020-03-18 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas'},
#  118: {'index': 2234,
#   'show_id': 's2801',
#   'type': 'Movie',
#   'title': 'Masameer - The Movie',
#   'director': 'Malik Nejer',
#   'country': 'Saudi Arabia',
#   'date_added': Timestamp('2020-03-19 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '100 min',
#   'listed_in': 'Comedies, International Movies'},
#  119: {'index': 2233,
#   'show_id': 's2800',
#   'type': 'Movie',
#   'title': 'Altered Carbon: Resleeved',
#   'director': 'Takeru Nakajima, Yoshiyuki Okada',
#   'country': 'Japan',
#   'date_added': Timestamp('2020-03-19 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '75 min',
#   'listed_in': 'Action & Adventure, Anime Features, International Movies'},
#  120: {'index': 7321,
#   'show_id': 's2795',
#   'type': 'TV Show',
#   'title': 'The Letter for the King',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, International TV Shows, TV Action & Adventure'},
#  121: {'index': 7322,
#   'show_id': 's2798',
#   'type': 'TV Show',
#   'title': 'Vampires',
#   'director': 'None',
#   'country': 'France',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas, TV Horror'},
#  122: {'index': 2227,
#   'show_id': 's2787',
#   'type': 'Movie',
#   'title': 'A Life of Speed: The Juan Manuel Fangio Story',
#   'director': 'Francisco Macri',
#   'country': 'Argentina',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '93 min',
#   'listed_in': 'Documentaries, International Movies, Sports Movies'},
#  123: {'index': 7319,
#   'show_id': 's2793',
#   'type': 'TV Show',
#   'title': 'She',
#   'director': 'None',
#   'country': 'India',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  124: {'index': 7318,
#   'show_id': 's2792',
#   'type': 'TV Show',
#   'title': 'Self Made: Inspired by the Life of Madam C.J. Walker',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Dramas'},
#  125: {'index': 2231,
#   'show_id': 's2797',
#   'type': 'Movie',
#   'title': 'Ultras',
#   'director': 'Francesco Lettieri',
#   'country': 'Italy',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '109 min',
#   'listed_in': 'Dramas, International Movies, Sports Movies'},
#  126: {'index': 7315,
#   'show_id': 's2791',
#   'type': 'TV Show',
#   'title': 'Greenhouse Academy',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '4 Seasons',
#   'listed_in': "Kids' TV, TV Dramas, Teen TV Shows"},
#  127: {'index': 7314,
#   'show_id': 's2789',
#   'type': 'TV Show',
#   'title': 'Dino Girl Gauko',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y7',
#   'duration': '2 Seasons',
#   'listed_in': "Anime Series, Kids' TV"},
#  128: {'index': 300,
#   'show_id': 's2788',
#   'type': 'TV Show',
#   'title': "Archibald's Next Big Thing",
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y7',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV, TV Comedies"},
#  129: {'index': 7320,
#   'show_id': 's2794',
#   'type': 'TV Show',
#   'title': 'The English Game',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, International TV Shows, TV Dramas'},
#  130: {'index': 2230,
#   'show_id': 's2796',
#   'type': 'TV Show',
#   'title': 'Tiger King: Murder, Mayhem and Madness',
#   'director': 'Eric Goode, Rebecca Chaiklin',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  131: {'index': 299,
#   'show_id': 's2786',
#   'type': 'TV Show',
#   'title': 'Barbie Dreamhouse Adventures: Go Team Roberts',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-03-21 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV"},
#  132: {'index': 7313,
#   'show_id': 's2785',
#   'type': 'TV Show',
#   'title': 'J-Style Trip',
#   'director': 'None',
#   'country': 'Taiwan',
#   'date_added': Timestamp('2020-03-22 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV'},
#  133: {'index': 7312,
#   'show_id': 's2784',
#   'type': 'TV Show',
#   'title': 'Freud',
#   'director': 'None',
#   'country': 'Austria',
#   'date_added': Timestamp('2020-03-23 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  134: {'index': 2226,
#   'show_id': 's2783',
#   'type': 'Movie',
#   'title': 'Tom Segura: Ball Hog',
#   'director': 'Rami Hachache',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-24 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '70 min',
#   'listed_in': 'Stand-Up Comedy'},
#  135: {'index': 2225,
#   'show_id': 's2782',
#   'type': 'Movie',
#   'title': 'The Occupant',
#   'director': 'Àlex Pastor, David Pastor',
#   'country': 'Spain',
#   'date_added': Timestamp('2020-03-25 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '104 min',
#   'listed_in': 'Independent Movies, International Movies, Thrillers'},
#  136: {'index': 7311,
#   'show_id': 's2780',
#   'type': 'Movie',
#   'title': 'Crip Camp: A Disability Revolution',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-25 00:00:00'),
#   'release_year': 2020,
#   'rating': 'R',
#   'duration': '108 min',
#   'listed_in': 'Documentaries'},
#  137: {'index': 7317,
#   'show_id': 's2775',
#   'type': 'TV Show',
#   'title': '7SEEDS',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-03-26 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Anime Series, International TV Shows'},
#  138: {'index': 2222,
#   'show_id': 's2777',
#   'type': 'Movie',
#   'title': 'Making Unorthodox',
#   'director': 'Marlene Melchior',
#   'country': 'Germany',
#   'date_added': Timestamp('2020-03-26 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-G',
#   'duration': '21 min',
#   'listed_in': 'Documentaries, International Movies'},
#  139: {'index': 7310,
#   'show_id': 's2778',
#   'type': 'TV Show',
#   'title': 'Unorthodox',
#   'director': 'None',
#   'country': 'Germany',
#   'date_added': Timestamp('2020-03-26 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas'},
#  140: {'index': 7309,
#   'show_id': 's2768',
#   'type': 'TV Show',
#   'title': 'Ozark',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'Crime TV Shows, TV Dramas, TV Thrillers'},
#  141: {'index': 298,
#   'show_id': 's2773',
#   'type': 'TV Show',
#   'title': 'Wassup Man GO!',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2020-03-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Korean TV Shows, Reality TV'},
#  142: {'index': 2214,
#   'show_id': 's2764',
#   'type': 'Movie',
#   'title': 'Dragons: Rescue Riders: Hunt for the Golden Dragon',
#   'director': 'TJ Sullivan, Greg Rankin',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y',
#   'duration': '46 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  143: {'index': 2219,
#   'show_id': 's2772',
#   'type': 'Movie',
#   'title': 'Uncorked',
#   'director': 'Prentice Penny',
#   'country': 'United States',
#   'date_added': Timestamp('2020-03-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '104 min',
#   'listed_in': 'Dramas, Independent Movies'},
#  144: {'index': 2218,
#   'show_id': 's2771',
#   'type': 'Movie',
#   'title': 'True: Wuzzle Wegg Day',
#   'director': 'Todd Kauffman, Mark Thornton',
#   'country': 'Canada',
#   'date_added': Timestamp('2020-03-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y',
#   'duration': '24 min',
#   'listed_in': 'Children & Family Movies'},
#  145: {'index': 2215,
#   'show_id': 's2767',
#   'type': 'Movie',
#   'title': 'Maska',
#   'director': 'Neeraj Udhwani',
#   'country': 'India',
#   'date_added': Timestamp('2020-03-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '112 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  146: {'index': 2216,
#   'show_id': 's2769',
#   'type': 'Movie',
#   'title': 'The Decline',
#   'director': 'Patrice Laliberté',
#   'country': 'Canada',
#   'date_added': Timestamp('2020-03-27 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '83 min',
# ...
#  904: {'index': 761,
#   'show_id': 's614',
#   'type': 'Movie',
#   'title': 'Voiceless',
#   'director': 'Robert O. Peters',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-07-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '112 min',
#   'listed_in': 'Dramas, International Movies, Thrillers'},
#  905: {'index': 736,
#   'show_id': 's588',
#   'type': 'TV Show',
#   'title': 'Quarantine Tales',
#   'director': 'Sidharta Tata, Aco Tenriyagelli, Dian Sastrowardoyo, Ifa Isfansyah, Jason Iskandar',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-07-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Comedies, TV Dramas'},
#  906: {'index': 706,
#   'show_id': 's555',
#   'type': 'Movie',
#   'title': 'RattleSnake - The Ahanna Story',
#   'director': 'Ramsey Nouah',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-07-02 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '136 min',
#   'listed_in': 'Dramas, International Movies, Thrillers'},
#  907: {'index': 703,
#   'show_id': 's553',
#   'type': 'Movie',
#   'title': 'Holiday on Mars',
#   'director': 'Neri Parenti',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-07-02 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '94 min',
#   'listed_in': 'Comedies, International Movies'},
#  908: {'index': 122,
#   'show_id': 's550',
#   'type': 'TV Show',
#   'title': 'Big Timber',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-07-02 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV'},
#  909: {'index': 6697,
#   'show_id': 's549',
#   'type': 'TV Show',
#   'title': "Grey's Anatomy",
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-07-03 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '17 Seasons',
#   'listed_in': 'Romantic TV Shows, TV Dramas'},
#  910: {'index': 6693,
#   'show_id': 's544',
#   'type': 'TV Show',
#   'title': 'Undercover',
#   'director': 'None',
#   'country': 'Belgium',
#   'date_added': Timestamp('2021-07-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Action & Adventure'},
#  911: {'index': 6692,
#   'show_id': 's541',
#   'type': 'TV Show',
#   'title': 'The Worst Witch',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-07-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-G',
#   'duration': '4 Seasons',
#   'listed_in': "British TV Shows, Kids' TV"},
#  912: {'index': 6695,
#   'show_id': 's546',
#   'type': 'TV Show',
#   'title': 'YooHoo to the Rescue',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-07-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y',
#   'duration': '3 Seasons',
#   'listed_in': "Kids' TV, Korean TV Shows"},
#  913: {'index': 6691,
#   'show_id': 's540',
#   'type': 'TV Show',
#   'title': 'The New Legends of Monkey',
#   'director': 'None',
#   'country': 'Australia',
#   'date_added': Timestamp('2021-07-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV, TV Action & Adventure, TV Sci-Fi & Fantasy"},
#  914: {'index': 695,
#   'show_id': 's519',
#   'type': 'Movie',
#   'title': 'Har Kisse Ke Hisse: Kaamyaab',
#   'director': 'Hardik Mehta',
#   'country': 'India',
#   'date_added': Timestamp('2021-07-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '105 min',
#   'listed_in': 'Dramas, International Movies'},
#  915: {'index': 6674,
#   'show_id': 's520',
#   'type': 'TV Show',
#   'title': 'I AM A KILLER',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-07-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'British TV Shows, Crime TV Shows, Docuseries'},
#  916: {'index': 693,
#   'show_id': 's506',
#   'type': 'Movie',
#   'title': 'Therapy',
#   'director': 'Anurin Nwunembom, Musing Derrick',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-07-07 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '85 min',
#   'listed_in': 'Dramas, International Movies'},
#  917: {'index': 691,
#   'show_id': 's499',
#   'type': 'Movie',
#   'title': 'Clash',
#   'director': 'Pascal Atuma',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-07-07 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '87 min',
#   'listed_in': 'Dramas, International Movies'},
#  918: {'index': 672,
#   'show_id': 's502',
#   'type': 'Movie',
#   'title': 'Mama Drama',
#   'director': 'Seyi Babatope',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-07-07 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '105 min',
#   'listed_in': 'Dramas, International Movies'},
#  919: {'index': 667,
#   'show_id': 's481',
#   'type': 'Movie',
#   'title': 'Finding Hubby',
#   'director': 'Femi D. Ogunsanwo',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-07-09 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '105 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  920: {'index': 634,
#   'show_id': 's474',
#   'type': 'Movie',
#   'title': 'Born to Play',
#   'director': 'Viridiana Lieberman',
#   'country': 'United States',
#   'date_added': Timestamp('2021-07-12 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '93 min',
#   'listed_in': 'Documentaries, Sports Movies'},
#  921: {'index': 601,
#   'show_id': 's439',
#   'type': 'Movie',
#   'title': '2 Weeks in Lagos',
#   'director': 'Kathryn Fasegha',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-07-16 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '107 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  922: {'index': 6651,
#   'show_id': 's435',
#   'type': 'TV Show',
#   'title': 'Okupas',
#   'director': 'None',
#   'country': 'Argentina',
#   'date_added': Timestamp('2021-07-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Classic & Cult TV, Crime TV Shows, International TV Shows'},
#  923: {'index': 586,
#   'show_id': 's434',
#   'type': 'Movie',
#   'title': 'Milkwater',
#   'director': 'Morgan Ingari',
#   'country': 'United States',
#   'date_added': Timestamp('2021-07-20 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '102 min',
#   'listed_in': 'Comedies, Dramas, Independent Movies'},
#  924: {'index': 583,
#   'show_id': 's430',
#   'type': 'Movie',
#   'title': 'Sanitation Day',
#   'director': 'Seyi Babatope',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-07-21 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '105 min',
#   'listed_in': 'Dramas, International Movies, Thrillers'},
#  925: {'index': 6646,
#   'show_id': 's392',
#   'type': 'TV Show',
#   'title': 'Wynonna Earp',
#   'director': 'None',
#   'country': 'Canada',
#   'date_added': Timestamp('2021-07-26 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '4 Seasons',
#   'listed_in': 'International TV Shows, TV Action & Adventure, TV Dramas'},
#  926: {'index': 529,
#   'show_id': 's368',
#   'type': 'Movie',
#   'title': "I'm Glad I Did",
#   'director': 'Selçuk Metin',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-07-30 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '114 min',
#   'listed_in': 'Documentaries, International Movies'},
#  927: {'index': 6571,
#   'show_id': 's325',
#   'type': 'TV Show',
#   'title': '44 Cats',
#   'director': 'None',
#   'country': 'Italy',
#   'date_added': Timestamp('2021-08-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y7',
#   'duration': '3 Seasons',
#   'listed_in': "Kids' TV"},
#  928: {'index': 6647,
#   'show_id': 's332',
#   'type': 'TV Show',
#   'title': 'Darwin’s Game',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-08-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Anime Series, International TV Shows, TV Thrillers'},
#  929: {'index': 410,
#   'show_id': 's299',
#   'type': 'Movie',
#   'title': "Quam's Money",
#   'director': 'Kayode Kasum',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-08-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '115 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  930: {'index': 682,
#   'show_id': 's295',
#   'type': 'Movie',
#   'title': 'Takizawa Kabuki ZERO 2020 The Movie',
#   'director': 'Hideaki Takizawa',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-08-07 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '139 min',
#   'listed_in': 'International Movies, Music & Musicals'},
#  931: {'index': 382,
#   'show_id': 's283',
#   'type': 'Movie',
#   'title': 'La diosa del asfalto',
#   'director': 'Julián Hernández',
#   'country': 'Mexico',
#   'date_added': Timestamp('2021-08-11 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '127 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies'},
#  932: {'index': 6617,
#   'show_id': 's267',
#   'type': 'TV Show',
#   'title': 'The Creative Indians',
#   'director': 'None',
#   'country': 'India',
#   'date_added': Timestamp('2021-08-15 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, International TV Shows'},
#  933: {'index': 329,
#   'show_id': 's269',
#   'type': 'Movie',
#   'title': 'Unroyal',
#   'director': 'Moses Inwang',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-08-15 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '97 min',
#   'listed_in': 'Dramas, International Movies'},
#  934: {'index': 368,
#   'show_id': 's257',
#   'type': 'Movie',
#   'title': 'Nneka The Pretty Serpent',
#   'director': 'Tosin Igho',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-08-18 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '140 min',
#   'listed_in': 'Dramas, International Movies'},
#  935: {'index': 367,
#   'show_id': 's259',
#   'type': 'Movie',
#   'title': 'Out of my league',
#   'director': 'Alice Filippi',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-08-18 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '92 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  936: {'index': 93,
#   'show_id': 's261',
#   'type': 'TV Show',
#   'title': 'The Defeated',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-08-18 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  937: {'index': 364,
#   'show_id': 's251',
#   'type': 'Movie',
#   'title': 'A Faraway Land',
#   'director': 'Veronica Velasco',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-08-19 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-PG',
#   'duration': '102 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  938: {'index': 303,
#   'show_id': 's228',
#   'type': 'Movie',
#   'title': 'Really Love',
#   'director': 'Angel Kristi Williams',
#   'country': 'United States',
#   'date_added': Timestamp('2021-08-25 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '95 min',
#   'listed_in': 'Dramas, Independent Movies, Romantic Movies'},
#  939: {'index': 322,
#   'show_id': 's230',
#   'type': 'Movie',
#   'title': 'The Old Ways',
#   'director': 'Christopher Alender',
#   'country': 'United States',
#   'date_added': Timestamp('2021-08-25 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '90 min',
#   'listed_in': 'Horror Movies'},
#  940: {'index': 47,
#   'show_id': 's190',
#   'type': 'TV Show',
#   'title': 'Bread Barbershop',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-08-28 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV, TV Comedies"},
#  941: {'index': 680,
#   'show_id': 's149',
#   'type': 'TV Show',
#   'title': 'HQ Barbers',
#   'director': 'Gerhard Mostert',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-01 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'TV Shows'},
#  942: {'index': 173,
#   'show_id': 's120',
#   'type': 'Movie',
#   'title': 'Here and There',
#   'director': 'JP Habac',
#   'country': 'Philippines',
#   'date_added': Timestamp('2021-09-02 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '99 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  943: {'index': 179,
#   'show_id': 's127',
#   'type': 'Movie',
#   'title': 'Shikara',
#   'director': 'Vidhu Vinod Chopra',
#   'country': 'India',
#   'date_added': Timestamp('2021-09-02 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '115 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  944: {'index': 167,
#   'show_id': 's104',
#   'type': 'Movie',
#   'title': 'Shadow Parties',
#   'director': 'Yemi Amodu',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-06 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '117 min',
#   'listed_in': 'Dramas, International Movies, Thrillers'},
#  945: {'index': 107,
#   'show_id': 's85',
#   'type': 'Movie',
#   'title': 'Omo Ghetto: the Saga',
#   'director': 'JJC Skillz, Funke Akindele',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-09-10 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '147 min',
#   'listed_in': 'Action & Adventure, Comedies, Dramas'},
#  946: {'index': 130,
#   'show_id': 's79',
#   'type': 'Movie',
#   'title': 'Tughlaq Durbar',
#   'director': 'Delhiprasad Deenadayalan',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-11 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-14',
#   'duration': '145 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  947: {'index': 58,
#   'show_id': 's48',
#   'type': 'TV Show',
#   'title': 'The Smart Money Woman',
#   'director': 'Bunmi Ajakaiye',
#   'country': 'South Africa',
#   'date_added': Timestamp('2021-09-16 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Comedies'},
#  948: {'index': 6577,
#   'show_id': 's33',
#   'type': 'TV Show',
#   'title': 'Sex Education',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-09-17 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'British TV Shows, International TV Shows, TV Comedies'},
#  949: {'index': 36,
#   'show_id': 's35',
#   'type': 'TV Show',
#   'title': 'Tayo and Little Wizards',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-17 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-Y7',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV"},
#  950: {'index': 25,
#   'show_id': 's17',
#   'type': 'Movie',
#   'title': "Europe's Most Dangerous Man: Otto Skorzeny in Spain",
#   'director': 'Pedro de Echave García, Pablo Azorín Williams',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-22 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '67 min',
#   'listed_in': 'Documentaries, International Movies'},
#  951: {'index': 6574,
#   'show_id': 's18',
#   'type': 'TV Show',
#   'title': 'Falsa identidad',
#   'director': 'None',
#   'country': 'Mexico',
#   'date_added': Timestamp('2021-09-22 00:00:00'),
#   'release_year': 2020,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Crime TV Shows, Spanish-Language TV Shows, TV Dramas'},
#  952: {'index': 0,
#   'show_id': 's1',
#   'type': 'Movie',
#   'title': 'Dick Johnson Is Dead',
#   'director': 'Kirsten Johnson',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-25 00:00:00'),
#   'release_year': 2020,
#   'rating': 'PG-13',
#   'duration': '90 min',
#   'listed_in': 'Documentaries'}}

# %%
#Dicionario correspondiente al DataFrame "mask21" 
dic21=mask21.reset_index().to_dict(orient="index")
dic21
# Out:
# {0: {'index': 7355,
#   'show_id': 's2921',
#   'type': 'TV Show',
#   'title': 'Love Is Blind',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2020-02-13 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV, Romantic TV Shows'},
#  1: {'index': 6992,
#   'show_id': 's1697',
#   'type': 'TV Show',
#   'title': 'Polly Pocket',
#   'director': 'None',
#   'country': 'Canada',
#   'date_added': Timestamp('2020-11-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV"},
#  2: {'index': 6948,
#   'show_id': 's1552',
#   'type': 'TV Show',
#   'title': 'Hilda',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2020-12-14 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV"},
#  3: {'index': 6917,
#   'show_id': 's1456',
#   'type': 'TV Show',
#   'title': 'Headspace Guide to Meditation',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-01 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-G',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Science & Nature TV'},
#  4: {'index': 6915,
#   'show_id': 's1449',
#   'type': 'TV Show',
#   'title': 'Cobra Kai',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-01 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '3 Seasons',
#   'listed_in': 'TV Action & Adventure, TV Comedies, TV Dramas'},
#  5: {'index': 6916,
#   'show_id': 's1450',
#   'type': 'TV Show',
#   'title': 'Dream Home Makeover',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-01 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-G',
#   'duration': '2 Seasons',
#   'listed_in': 'Reality TV'},
#  6: {'index': 6920,
#   'show_id': 's1461',
#   'type': 'TV Show',
#   'title': 'Monarca',
#   'director': 'None',
#   'country': 'Mexico',
#   'date_added': Timestamp('2021-01-01 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'International TV Shows, Spanish-Language TV Shows, TV Dramas'},
#  7: {'index': 1337,
#   'show_id': 's1469',
#   'type': 'Movie',
#   'title': 'What Happened to Mr. Cha?',
#   'director': 'Kim Dong-kyu',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-01-01 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '102 min',
#   'listed_in': 'Comedies, International Movies'},
#  8: {'index': 6922,
#   'show_id': 's1467',
#   'type': 'Movie',
#   'title': 'The Minimalists: Less Is Now',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-01 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '54 min',
#   'listed_in': 'Documentaries'},
#  9: {'index': 6562,
#   'show_id': 's8438',
#   'type': 'TV Show',
#   'title': 'The Netflix Afterparty',
#   'director': 'Krysia Plonka, Kristian Mercado',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-02 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Stand-Up Comedy & Talk Shows, TV Comedies'},
#  10: {'index': 6912,
#   'show_id': 's1440',
#   'type': 'TV Show',
#   'title': 'History of Swear Words',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, TV Comedies'},
#  11: {'index': 6913,
#   'show_id': 's1441',
#   'type': 'TV Show',
#   'title': 'Nailed It! Mexico',
#   'director': 'None',
#   'country': 'Mexico',
#   'date_added': Timestamp('2021-01-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '3 Seasons',
#   'listed_in': 'International TV Shows, Reality TV, Spanish-Language TV Shows'},
#  12: {'index': 1313,
#   'show_id': 's1437',
#   'type': 'Movie',
#   'title': 'Ratones Paranoicos: The Band that Rocked Argentina',
#   'director': 'Alejandro Ruax, Ramiro Martínez',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-01-06 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '76 min',
#   'listed_in': 'Documentaries, International Movies, Music & Musicals'},
#  13: {'index': 6911,
#   'show_id': 's1438',
#   'type': 'TV Show',
#   'title': 'Surviving Death',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-06 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Reality TV'},
#  14: {'index': 1315,
#   'show_id': 's1433',
#   'type': 'TV Show',
#   'title': 'The Idhun Chronicles',
#   'director': 'Maite Ruiz De Austri',
#   'country': 'Spain',
#   'date_added': Timestamp('2021-01-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '2 Seasons',
#   'listed_in': 'Anime Series, International TV Shows, Spanish-Language TV Shows'},
#  15: {'index': 6906,
#   'show_id': 's1426',
#   'type': 'Movie',
#   'title': "Creating The Queen's Gambit",
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '14 min',
#   'listed_in': 'Documentaries'},
#  16: {'index': 6908,
#   'show_id': 's1430',
#   'type': 'TV Show',
#   'title': 'Mighty Little Bheem: Kite Festival',
#   'director': 'None',
#   'country': 'India',
#   'date_added': Timestamp('2021-01-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV, TV Comedies"},
#  17: {'index': 6909,
#   'show_id': 's1431',
#   'type': 'TV Show',
#   'title': 'Pretend It’s a City',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries'},
#  18: {'index': 6907,
#   'show_id': 's1428',
#   'type': 'TV Show',
#   'title': 'Inside the World’s Toughest Prisons',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-01-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '5 Seasons',
#   'listed_in': 'British TV Shows, Crime TV Shows, Docuseries'},
#  19: {'index': 1311,
#   'show_id': 's1425',
#   'type': 'Movie',
#   'title': 'Charming',
#   'director': 'Ross Venokur',
#   'country': 'Canada',
#   'date_added': Timestamp('2021-01-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '85 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  20: {'index': 6910,
#   'show_id': 's1432',
#   'type': 'Movie',
#   'title': 'Stuck Apart',
#   'director': 'None',
#   'country': 'Turkey',
#   'date_added': Timestamp('2021-01-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '97 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  21: {'index': 1307,
#   'show_id': 's1421',
#   'type': 'Movie',
#   'title': 'Crack: Cocaine, Corruption & Conspiracy',
#   'director': 'Stanley Nelson',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-11 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '90 min',
#   'listed_in': 'Documentaries'},
#  22: {'index': 1296,
#   'show_id': 's1419',
#   'type': 'Movie',
#   'title': 'Chris Rock Total Blackout: The Tamborine Extended Cut',
#   'director': 'Chris Rock',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-01-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '98 min',
#   'listed_in': 'Stand-Up Comedy'},
#  23: {'index': 1304,
#   'show_id': 's1417',
#   'type': 'TV Show',
#   'title': 'Night Stalker: The Hunt for a Serial Killer',
#   'director': 'Tiller Russell',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-13 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  24: {'index': 6902,
#   'show_id': 's1401',
#   'type': 'TV Show',
#   'title': 'Bling Empire',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV'},
#  25: {'index': 6903,
#   'show_id': 's1402',
#   'type': 'TV Show',
#   'title': 'Carmen Sandiego',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '4 Seasons',
#   'listed_in': "Kids' TV, TV Thrillers"},
#  26: {'index': 6904,
#   'show_id': 's1403',
#   'type': 'TV Show',
#   'title': 'Disenchantment',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '3 Seasons',
#   'listed_in': 'TV Action & Adventure, TV Comedies, TV Sci-Fi & Fantasy'},
#  27: {'index': 1299,
#   'show_id': 's1412',
#   'type': 'Movie',
#   'title': 'What Would Sophia Loren Do?',
#   'director': 'Ross Kauffman',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '32 min',
#   'listed_in': 'Documentaries'},
#  28: {'index': 1298,
#   'show_id': 's1411',
#   'type': 'Movie',
#   'title': 'Tribhanga - Tedhi Medhi Crazy',
#   'director': 'Renuka Shahane',
#   'country': 'India',
#   'date_added': Timestamp('2021-01-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '96 min',
#   'listed_in': 'Dramas, International Movies'},
#  29: {'index': 1293,
#   'show_id': 's1406',
#   'type': 'Movie',
#   'title': 'Outside the Wire',
#   'director': 'Mikael Håfström',
#   'country': 'Hungary',
#   'date_added': Timestamp('2021-01-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'R',
#   'duration': '116 min',
#   'listed_in': 'Action & Adventure'},
#  30: {'index': 1300,
#   'show_id': 's1413',
#   'type': 'Movie',
#   'title': 'Wish You',
#   'director': 'Sung Do-jun',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-01-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '102 min',
#   'listed_in': 'Dramas, International Movies, LGBTQ Movies'},
#  31: {'index': 6901,
#   'show_id': 's1396',
#   'type': 'TV Show',
#   'title': 'Hello Ninja',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-19 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y',
#   'duration': '4 Seasons',
#   'listed_in': "Kids' TV"},
#  32: {'index': 6899,
#   'show_id': 's1393',
#   'type': 'TV Show',
#   'title': 'Daughter From Another Mother',
#   'director': 'None',
#   'country': 'Mexico',
#   'date_added': Timestamp('2021-01-20 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Spanish-Language TV Shows, TV Comedies'},
#  33: {'index': 6900,
#   'show_id': 's1395',
#   'type': 'TV Show',
#   'title': 'Spycraft',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-20 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Science & Nature TV'},
#  34: {'index': 1283,
#   'show_id': 's1389',
#   'type': 'Movie',
#   'title': 'The White Tiger',
#   'director': 'Ramin Bahrani',
#   'country': 'India',
#   'date_added': Timestamp('2021-01-22 00:00:00'),
#   'release_year': 2021,
#   'rating': 'R',
#   'duration': '127 min',
#   'listed_in': 'Dramas'},
#  35: {'index': 6896,
#   'show_id': 's1385',
#   'type': 'TV Show',
#   'title': 'Busted!',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-01-22 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '3 Seasons',
#   'listed_in': 'Crime TV Shows, International TV Shows, Korean TV Shows'},
#  36: {'index': 6895,
#   'show_id': 's1384',
#   'type': 'TV Show',
#   'title': 'Blown Away',
#   'director': 'None',
#   'country': 'Canada',
#   'date_added': Timestamp('2021-01-22 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '2 Seasons',
#   'listed_in': 'International TV Shows, Reality TV'},
#  37: {'index': 6894,
#   'show_id': 's1381',
#   'type': 'TV Show',
#   'title': 'Go Dog Go',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-26 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV"},
#  38: {'index': 1279,
#   'show_id': 's1379',
#   'type': 'Movie',
#   'title': 'Penguin Bloom',
#   'director': 'Glendyn Ivin',
#   'country': 'Australia',
#   'date_added': Timestamp('2021-01-27 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '95 min',
#   'listed_in': 'Children & Family Movies, Dramas'},
#  39: {'index': 6892,
#   'show_id': 's1376',
#   'type': 'TV Show',
#   'title': 'BONDING',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-27 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'TV Comedies, TV Dramas'},
#  40: {'index': 6891,
#   'show_id': 's1374',
#   'type': 'TV Show',
#   'title': '50M2',
#   'director': 'None',
#   'country': 'Turkey',
#   'date_added': Timestamp('2021-01-27 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas, TV Thrillers'},
#  41: {'index': 1277,
#   'show_id': 's1375',
#   'type': 'Movie',
#   'title': 'Accomplice',
#   'director': 'Jeremy Grant',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-27 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '52 min',
#   'listed_in': 'Documentaries, International Movies, Sports Movies'},
#  42: {'index': 1275,
#   'show_id': 's1373',
#   'type': 'Movie',
#   'title': 'June & Kopi',
#   'director': 'Noviandra Santosa',
#   'country': 'Indonesia',
#   'date_added': Timestamp('2021-01-28 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '90 min',
#   'listed_in': 'Children & Family Movies, Dramas, International Movies'},
#  43: {'index': 6890,
#   'show_id': 's1372',
#   'type': 'TV Show',
#   'title': 'We Are: The Brooklyn Saints',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-29 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries'},
#  44: {'index': 1271,
#   'show_id': 's1369',
#   'type': 'Movie',
#   'title': 'Below Zero',
#   'director': 'Lluís Quílez',
#   'country': 'Spain',
#   'date_added': Timestamp('2021-01-29 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '107 min',
#   'listed_in': 'Action & Adventure, International Movies'},
#  45: {'index': 1272,
#   'show_id': 's1370',
#   'type': 'Movie',
#   'title': 'Finding ‘Ohana',
#   'director': 'Jude Weng',
#   'country': 'United States',
#   'date_added': Timestamp('2021-01-29 00:00:00'),
#   'release_year': 2021,
#   'rating': 'PG',
#   'duration': '123 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  46: {'index': 1273,
#   'show_id': 's1371',
#   'type': 'Movie',
#   'title': 'The Dig',
#   'director': 'Simon Stone',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-01-29 00:00:00'),
#   'release_year': 2021,
#   'rating': 'PG-13',
#   'duration': '113 min',
#   'listed_in': 'Dramas, International Movies'},
#  47: {'index': 6883,
#   'show_id': 's1353',
#   'type': 'TV Show',
#   'title': 'Tiffany Haddish Presents: They Ready',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-02 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Stand-Up Comedy & Talk Shows, TV Comedies'},
#  48: {'index': 6880,
#   'show_id': 's1349',
#   'type': 'TV Show',
#   'title': 'Firefly Lane',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-03 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Romantic TV Shows, TV Dramas'},
#  49: {'index': 6877,
#   'show_id': 's1339',
#   'type': 'TV Show',
#   'title': 'Hache',
#   'director': 'None',
#   'country': 'Spain',
#   'date_added': Timestamp('2021-02-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Crime TV Shows, International TV Shows, Spanish-Language TV Shows'},
#  50: {'index': 6878,
#   'show_id': 's1340',
#   'type': 'TV Show',
#   'title': 'Invisible City',
#   'director': 'None',
#   'country': 'Brazil',
#   'date_added': Timestamp('2021-02-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Dramas'},
#  51: {'index': 1259,
#   'show_id': 's1346',
#   'type': 'Movie',
#   'title': 'The Yin-Yang Master: Dream Of Eternity',
#   'director': 'Guo Jingming',
#   'country': 'China',
#   'date_added': Timestamp('2021-02-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '133 min',
#   'listed_in': 'Action & Adventure, International Movies'},
#  52: {'index': 1257,
#   'show_id': 's1344',
#   'type': 'Movie',
#   'title': 'Strip Down, Rise Up',
#   'director': 'Michèle Ohayon',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'R',
#   'duration': '113 min',
#   'listed_in': 'Documentaries'},
#  53: {'index': 1256,
#   'show_id': 's1343',
#   'type': 'Movie',
#   'title': 'Space Sweepers',
#   'director': 'Jo Sung-hee',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-02-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '138 min',
#   'listed_in': 'Action & Adventure, Dramas, International Movies'},
#  54: {'index': 1255,
#   'show_id': 's1342',
#   'type': 'Movie',
#   'title': 'Malcolm & Marie',
#   'director': 'Sam Levinson',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'R',
#   'duration': '106 min',
#   'listed_in': 'Dramas, Independent Movies'},
#  55: {'index': 1248,
#   'show_id': 's1330',
#   'type': 'Movie',
#   'title': 'The Misadventures of Hedi and Cokeman',
#   'director': 'Julien Royal',
#   'country': 'France',
#   'date_added': Timestamp('2021-02-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '99 min',
#   'listed_in': 'Comedies, International Movies'},
#  56: {'index': 1247,
#   'show_id': 's1329',
#   'type': 'TV Show',
#   'title': 'Crime Scene: The Vanishing at the Cecil Hotel',
#   'director': 'Joe Berlinger',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  57: {'index': 1243,
#   'show_id': 's1326',
#   'type': 'Movie',
#   'title': 'Red Dot',
#   'director': 'Alain Darborg',
#   'country': 'Sweden',
#   'date_added': Timestamp('2021-02-11 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '86 min',
#   'listed_in': 'International Movies, Thrillers'},
#  58: {'index': 1244,
#   'show_id': 's1327',
#   'type': 'Movie',
#   'title': 'Squared Love',
#   'director': 'Filip Zylber',
#   'country': 'Poland',
#   'date_added': Timestamp('2021-02-11 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '102 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies'},
#  59: {'index': 6871,
#   'show_id': 's1318',
#   'type': 'TV Show',
#   'title': 'Nadiya Bakes',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-02-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-G',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, International TV Shows, Reality TV'},
#  60: {'index': 1239,
#   'show_id': 's1320',
#   'type': 'Movie',
#   'title': "Xico's Journey",
#   'director': 'Eric D. Cabello Díaz',
#   'country': 'Mexico',
#   'date_added': Timestamp('2021-02-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '87 min',
#   'listed_in': 'Children & Family Movies'},
#  61: {'index': 1238,
#   'show_id': 's1319',
#   'type': 'Movie',
#   'title': 'To All The Boys: Always And Forever',
#   'director': 'Michael Fimognari',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '116 min',
#   'listed_in': 'Comedies, Romantic Movies'},
#  62: {'index': 6870,
#   'show_id': 's1314',
#   'type': 'TV Show',
#   'title': 'Buried by the Bernards',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV'},
#  63: {'index': 1236,
#   'show_id': 's1316',
#   'type': 'Movie',
#   'title': 'Hate by Dani Rovira',
#   'director': 'Mario Briongos',
#   'country': 'Spain',
#   'date_added': Timestamp('2021-02-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '83 min',
#   'listed_in': 'Stand-Up Comedy'},
#  64: {'index': 1234,
#   'show_id': 's1312',
#   'type': 'Movie',
#   'title': 'Namaste Wahala',
#   'director': 'Hamisha Daryani Ahuja',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-02-14 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '107 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  65: {'index': 1245,
#   'show_id': 's1309',
#   'type': 'TV Show',
#   'title': 'Booba',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-02-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '4 Seasons',
#   'listed_in': "Kids' TV, TV Comedies"},
#  66: {'index': 6869,
#   'show_id': 's1311',
#   'type': 'TV Show',
#   'title': 'The Crew',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies'},
#  67: {'index': 1230,
#   'show_id': 's1305',
#   'type': 'Movie',
#   'title': 'Animals on the Loose: A You vs. Wild Movie',
#   'director': 'Ben Simms',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-16 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '139 min',
#   'listed_in': 'Children & Family Movies'},
#  68: {'index': 6868,
#   'show_id': 's1303',
#   'type': 'TV Show',
#   'title': 'MeatEater',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-17 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '4 Seasons',
#   'listed_in': 'Docuseries, Reality TV, Science & Nature TV'},
#  69: {'index': 6866,
#   'show_id': 's1301',
#   'type': 'TV Show',
#   'title': 'Amend: The Fight for America',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-17 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries'},
#  70: {'index': 6867,
#   'show_id': 's1302',
#   'type': 'TV Show',
#   'title': 'Behind Her Eyes',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-02-17 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, International TV Shows, TV Dramas'},
#  71: {'index': 6864,
#   'show_id': 's1297',
#   'type': 'TV Show',
#   'title': 'Hello, Me!',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-02-18 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Comedies'},
#  72: {'index': 6865,
#   'show_id': 's1299',
#   'type': 'TV Show',
#   'title': 'Sisyphus',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-02-18 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Action & Adventure, TV Dramas'},
#  73: {'index': 214,
#   'show_id': 's1300',
#   'type': 'TV Show',
#   'title': 'Thus Spoke Kishibe Rohan',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-02-18 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Anime Series, International TV Shows'},
#  74: {'index': 1225,
#   'show_id': 's1294',
#   'type': 'TV Show',
#   'title': 'Pitta Kathalu',
#   'director': 'Tharun Bhascker Dhaassyam, B. V. Nandini Reddy, Nag Ashwin, Sankalp Reddy',
#   'country': 'India',
#   'date_added': Timestamp('2021-02-19 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas'},
#  75: {'index': 1222,
#   'show_id': 's1291',
#   'type': 'Movie',
#   'title': 'I Care a Lot',
#   'director': 'J Blakeson',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-02-19 00:00:00'),
#   'release_year': 2021,
#   'rating': 'R',
#   'duration': '118 min',
#   'listed_in': 'Comedies, LGBTQ Movies, Thrillers'},
#  76: {'index': 6863,
#   'show_id': 's1295',
#   'type': 'TV Show',
#   'title': 'Tribes of Europa',
#   'director': 'None',
#   'country': 'Germany',
#   'date_added': Timestamp('2021-02-19 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Action & Adventure, TV Dramas'},
#  77: {'index': 6862,
#   'show_id': 's1288',
#   'type': 'Movie',
#   'title': 'Fate: The Winx Saga - The Afterparty',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-02-20 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '36 min',
#   'listed_in': 'Comedies, Dramas'},
#  78: {'index': 6860,
#   'show_id': 's1286',
#   'type': 'TV Show',
#   'title': 'Vincenzo',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-02-21 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Comedies, TV Dramas'},
#  79: {'index': 1217,
#   'show_id': 's1282',
#   'type': 'Movie',
#   'title': 'Red',
#   'director': 'Tirumala Kishore',
#   'country': 'India',
#   'date_added': Timestamp('2021-02-23 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '143 min',
#   'listed_in': 'Dramas, International Movies'},
#  80: {'index': 1216,
#   'show_id': 's1281',
#   'type': 'Movie',
#   'title': 'Pelé',
#   'director': 'David Tryhorn, Ben Nicholas',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-02-23 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '109 min',
#   'listed_in': 'Documentaries, International Movies, Sports Movies'},
#  81: {'index': 1214,
#   'show_id': 's1279',
#   'type': 'Movie',
#   'title': 'Brian Regan: On the Rocks',
#   'director': 'Troy Miller',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-23 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-G',
#   'duration': '58 min',
#   'listed_in': 'Stand-Up Comedy'},
#  82: {'index': 6858,
#   'show_id': 's1278',
#   'type': 'TV Show',
#   'title': 'Two Sentence Horror Stories',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '2 Seasons',
#   'listed_in': 'TV Horror, Teen TV Shows'},
#  83: {'index': 6857,
#   'show_id': 's1276',
#   'type': 'TV Show',
#   'title': 'Ginny & Georgia',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Romantic TV Shows, TV Comedies, TV Dramas'},
#  84: {'index': 6856,
#   'show_id': 's1275',
#   'type': 'TV Show',
#   'title': 'Canine Intervention',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV'},
#  85: {'index': 6855,
#   'show_id': 's1273',
#   'type': 'TV Show',
#   'title': 'Age of Samurai: Battle for Japan',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-02-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, International TV Shows'},
#  86: {'index': 1211,
#   'show_id': 's1270',
#   'type': 'Movie',
#   'title': 'Geez & Ann',
#   'director': 'Rizki Balki',
#   'country': 'Indonesia',
#   'date_added': Timestamp('2021-02-25 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '106 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  87: {'index': 1208,
#   'show_id': 's1266',
#   'type': 'Movie',
#   'title': 'The Girl on the Train',
#   'director': 'Ribhu Dasgupta',
#   'country': 'India',
#   'date_added': Timestamp('2021-02-26 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '120 min',
#   'listed_in': 'International Movies, Thrillers'},
#  88: {'index': 1204,
#   'show_id': 's1261',
#   'type': 'Movie',
#   'title': 'Crazy About Her',
#   'director': 'Dani de la Orden',
#   'country': 'Spain',
#   'date_added': Timestamp('2021-02-26 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '107 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies'},
#  89: {'index': 209,
#   'show_id': 's1263',
#   'type': 'Movie',
#   'title': 'Ginny & Georgia - The Afterparty',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-02-26 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '35 min',
#   'listed_in': 'Comedies, Dramas'},
#  90: {'index': 1202,
#   'show_id': 's1259',
#   'type': 'Movie',
#   'title': 'Bigfoot Family',
#   'director': 'Jérémie Degruson, Ben Stassen',
#   'country': 'Belgium',
#   'date_added': Timestamp('2021-02-26 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '88 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  91: {'index': 1194,
#   'show_id': 's1251',
#   'type': 'Movie',
#   'title': 'Connected',
#   'director': 'Milton Kremer',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-03-01 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-G',
#   'duration': '42 min',
#   'listed_in': 'Documentaries, International Movies, Music & Musicals'},
#  92: {'index': 1193,
#   'show_id': 's1250',
#   'type': 'Movie',
#   'title': 'Blanche Gardin: The All-Nighter',
#   'director': 'Xavier Maingon, Marc-Antoine Hélard',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-03-01 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '96 min',
#   'listed_in': 'Stand-Up Comedy'},
#  93: {'index': 1191,
#   'show_id': 's1249',
#   'type': 'Movie',
#   'title': 'Biggie: I Got a Story to Tell',
#   'director': 'Emmett Malloy',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-01 00:00:00'),
#   'release_year': 2021,
#   'rating': 'R',
#   'duration': '98 min',
#   'listed_in': 'Documentaries, Music & Musicals'},
#  94: {'index': 6850,
#   'show_id': 's1246',
#   'type': 'TV Show',
#   'title': 'Word Party',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-02 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y',
#   'duration': '5 Seasons',
#   'listed_in': "Kids' TV"},
#  95: {'index': 1187,
#   'show_id': 's1242',
#   'type': 'Movie',
#   'title': 'Moxie',
#   'director': 'Amy Poehler',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-03 00:00:00'),
#   'release_year': 2021,
#   'rating': 'PG-13',
#   'duration': '112 min',
#   'listed_in': 'Comedies, Dramas, Music & Musicals'},
#  96: {'index': 1188,
#   'show_id': 's1243',
#   'type': 'TV Show',
#   'title': 'Murder Among the Mormons',
#   'director': 'Jared Hess, Tyler Measom',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-03 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries'},
#  97: {'index': 6849,
#   'show_id': 's1239',
#   'type': 'TV Show',
#   'title': 'Pacific Rim: The Black',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-04 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Anime Series'},
#  98: {'index': 194,
#   'show_id': 's1236',
#   'type': 'TV Show',
#   'title': 'Pokémon Journeys: The Series',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-03-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '4 Seasons',
#   'listed_in': "Anime Series, Kids' TV, TV Action & Adventure"},
#  99: {'index': 6848,
#   'show_id': 's1232',
#   'type': 'TV Show',
#   'title': 'City of Ghosts',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV"},
#  100: {'index': 1183,
#   'show_id': 's1237',
#   'type': 'Movie',
#   'title': 'Sentinelle',
#   'director': 'Julien Leclercq',
#   'country': 'France',
#   'date_added': Timestamp('2021-03-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '81 min',
#   'listed_in': 'Action & Adventure, Dramas, International Movies'},
#  101: {'index': 1182,
#   'show_id': 's1235',
#   'type': 'TV Show',
#   'title': 'Nevenka: Breaking the Silence',
#   'director': 'Maribel Sánchez-Maroto',
#   'country': 'Spain',
#   'date_added': Timestamp('2021-03-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, International TV Shows, Spanish-Language TV Shows'},
#  102: {'index': 1179,
#   'show_id': 's1231',
#   'type': 'Movie',
#   'title': 'Aelay',
#   'director': 'Halitha Shameem',
#   'country': 'India',
#   'date_added': Timestamp('2021-03-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '151 min',
#   'listed_in': 'Comedies, Dramas, Independent Movies'},
#  103: {'index': 1180,
#   'show_id': 's1233',
#   'type': 'Movie',
#   'title': 'Dogwashers',
#   'director': 'Carlos Moreno',
#   'country': 'Colombia',
#   'date_added': Timestamp('2021-03-05 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '108 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  104: {'index': 6846,
#   'show_id': 's1228',
#   'type': 'TV Show',
#   'title': 'Bombay Begums',
#   'director': 'None',
#   'country': 'India',
#   'date_added': Timestamp('2021-03-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas'},
#  105: {'index': 1178,
#   'show_id': 's1229',
#   'type': 'Movie',
#   'title': 'Bombay Rose',
#   'director': 'Gitanjali Rao',
#   'country': 'India',
#   'date_added': Timestamp('2021-03-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'PG-13',
#   'duration': '97 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies'},
#  106: {'index': 6845,
#   'show_id': 's1227',
#   'type': 'TV Show',
#   'title': 'The Houseboat',
#   'director': 'None',
#   'country': 'Germany',
#   'date_added': Timestamp('2021-03-09 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, International TV Shows'},
#  107: {'index': 193,
#   'show_id': 's1226',
#   'type': 'TV Show',
#   'title': 'Marriage or Mortgage',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-03-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-G',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV, Romantic TV Shows'},
#  108: {'index': 192,
#   'show_id': 's1225',
#   'type': 'TV Show',
#   'title': 'Last Chance U: Basketball',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-03-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries'},
#  109: {'index': 1177,
#   'show_id': 's1224',
#   'type': 'TV Show',
#   'title': 'Dealer',
#   'director': 'Ange Basterga, Nicolas Lopez',
#   'country': 'France',
#   'date_added': Timestamp('2021-03-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Action & Adventure'},
#  110: {'index': 1174,
#   'show_id': 's1221',
#   'type': 'Movie',
#   'title': 'Coven of Sisters',
#   'director': 'Pablo Agüero',
#   'country': 'Spain',
#   'date_added': Timestamp('2021-03-11 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '92 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies'},
#  111: {'index': 1168,
#   'show_id': 's1213',
#   'type': 'Movie',
#   'title': 'Paper Lives',
#   'director': 'Can Ulkay',
#   'country': 'Turkey',
#   'date_added': Timestamp('2021-03-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '97 min',
#   'listed_in': 'Dramas, International Movies'},
#  112: {'index': 1172,
#   'show_id': 's1219',
#   'type': 'Movie',
#   'title': 'YES DAY',
#   'director': 'Miguel Arteta',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'PG',
#   'duration': '90 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  113: {'index': 6844,
#   'show_id': 's1218',
#   'type': 'TV Show',
#   'title': 'The One',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-03-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, Crime TV Shows, International TV Shows'},
#  114: {'index': 6843,
#   'show_id': 's1214',
#   'type': 'TV Show',
#   'title': 'Paradise PD',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'TV Comedies'},
#  115: {'index': 6841,
#   'show_id': 's1211',
#   'type': 'TV Show',
#   'title': 'Love Alarm',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-03-12 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'International TV Shows, Korean TV Shows, Romantic TV Shows'},
#  116: {'index': 6840,
#   'show_id': 's1207',
#   'type': 'TV Show',
#   'title': 'Zero Chill',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-03-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-G',
#   'duration': '1 Season',
#   'listed_in': "British TV Shows, Kids' TV, TV Dramas"},
#  117: {'index': 6839,
#   'show_id': 's1206',
#   'type': 'TV Show',
#   'title': 'The Lost Pirate Kingdom',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Science & Nature TV, TV Action & Adventure'},
#  118: {'index': 6838,
#   'show_id': 's1202',
#   'type': 'TV Show',
#   'title': 'Abla Fahita: Drama Queen',
#   'director': 'None',
#   'country': 'Egypt',
#   'date_added': Timestamp('2021-03-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Comedies'},
#  119: {'index': 1160,
#   'show_id': 's1203',
#   'type': 'Movie',
#   'title': 'C/O Kaadhal',
#   'director': 'Hemambar Jasti',
#   'country': 'India',
#   'date_added': Timestamp('2021-03-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '131 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  120: {'index': 6837,
#   'show_id': 's1201',
#   'type': 'TV Show',
#   'title': 'Waffles + Mochi',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-16 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV"},
#  121: {'index': 1158,
#   'show_id': 's1199',
#   'type': 'Movie',
#   'title': 'RebellComedy: Straight Outta the Zoo',
#   'director': 'Ladislaus Kiraly',
#   'country': 'Germany',
#   'date_added': Timestamp('2021-03-16 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '74 min',
#   'listed_in': 'Stand-Up Comedy'},
#  122: {'index': 1155,
#   'show_id': 's1196',
#   'type': 'Movie',
#   'title': 'Operation Varsity Blues:\xa0The\xa0College\xa0Admissions\xa0Scandal',
#   'director': 'Chris Smith',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-17 00:00:00'),
#   'release_year': 2021,
#   'rating': 'R',
#   'duration': '100 min',
#   'listed_in': 'Documentaries'},
#  123: {'index': 1156,
#   'show_id': 's1197',
#   'type': 'TV Show',
#   'title': 'Under Suspicion: Uncovering the Wesphael Case',
#   'director': 'Alain Brunard',
#   'country': 'Belgium',
#   'date_added': Timestamp('2021-03-17 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries, International TV Shows'},
#  124: {'index': 1148,
#   'show_id': 's1188',
#   'type': 'Movie',
#   'title': 'Deadly Illusions',
#   'director': 'Anna Elizabeth James',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-18 00:00:00'),
#   'release_year': 2021,
#   'rating': 'R',
#   'duration': '115 min',
#   'listed_in': 'Thrillers'},
#  125: {'index': 1149,
#   'show_id': 's1189',
#   'type': 'Movie',
#   'title': 'Get the Goat',
#   'director': 'Vitor Brandt',
#   'country': 'Brazil',
#   'date_added': Timestamp('2021-03-18 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '98 min',
#   'listed_in': 'Action & Adventure, Comedies, International Movies'},
#  126: {'index': 1150,
#   'show_id': 's1190',
#   'type': 'Movie',
#   'title': 'Nate Bargatze: The Greatest Average American',
#   'director': 'Troy Miller',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-18 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-G',
#   'duration': '60 min',
#   'listed_in': 'Stand-Up Comedy'},
#  127: {'index': 6836,
#   'show_id': 's1187',
#   'type': 'TV Show',
#   'title': 'B: The Beginning',
#   'director': 'None',
#   'country': 'Japan',
#   'date_added': Timestamp('2021-03-18 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'Anime Series, Crime TV Shows, International TV Shows'},
#  128: {'index': 191,
#   'show_id': 's1181',
#   'type': 'TV Show',
#   'title': 'Alien TV',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-03-19 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '2 Seasons',
#   'listed_in': "Kids' TV, TV Comedies"},
#  129: {'index': 6834,
#   'show_id': 's1182',
#   'type': 'TV Show',
#   'title': 'Country Comfort',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-19 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies'},
#  130: {'index': 6835,
#   'show_id': 's1183',
#   'type': 'TV Show',
#   'title': 'Formula 1: Drive to Survive',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-03-19 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'Docuseries'},
#  131: {'index': 1146,
#   'show_id': 's1185',
#   'type': 'Movie',
#   'title': 'The Yin Yang Master',
#   'director': 'Li Weiran',
#   'country': 'China',
#   'date_added': Timestamp('2021-03-19 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '120 min',
#   'listed_in': 'Action & Adventure, International Movies'},
#  132: {'index': 1139,
#   'show_id': 's1173',
#   'type': 'Movie',
#   'title': 'Loyiso Gola: Unlearning',
#   'director': 'Kagiso Lediga',
#   'country': 'South Africa',
#   'date_added': Timestamp('2021-03-23 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '60 min',
#   'listed_in': 'Stand-Up Comedy'},
#  133: {'index': 1140,
#   'show_id': 's1174',
#   'type': 'TV Show',
#   'title': 'Men on a Mission',
#   'director': 'Jung-ah Im',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-03-23 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '6 Seasons',
#   'listed_in': 'International TV Shows, Korean TV Shows, Stand-Up Comedy & Talk Shows'},
#  134: {'index': 6832,
#   'show_id': 's1175',
#   'type': 'TV Show',
#   'title': 'Navillera',
#   'director': 'None',
#   'country': 'South Korea',
#   'date_added': Timestamp('2021-03-23 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas'},
#  135: {'index': 1138,
#   'show_id': 's1172',
#   'type': 'Movie',
#   'title': 'Seaspiracy',
#   'director': 'Ali Tabrizi',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '90 min',
#   'listed_in': 'Documentaries'},
#  136: {'index': 6830,
#   'show_id': 's1169',
#   'type': 'TV Show',
#   'title': "DOTA: Dragon's Blood",
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-25 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Anime Series'},
#  137: {'index': 6831,
#   'show_id': 's1170',
#   'type': 'TV Show',
#   'title': 'Pui Pui Molcar',
#   'director': 'None',
#   'country': 'Japan',
#   'date_added': Timestamp('2021-03-25 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV"},
#  138: {'index': 1136,
#   'show_id': 's1168',
#   'type': 'Movie',
#   'title': 'Caught by a Wave',
#   'director': 'Massimiliano Camaiti',
#   'country': 'Italy',
#   'date_added': Timestamp('2021-03-25 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '100 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  139: {'index': 1137,
#   'show_id': 's1171',
#   'type': 'Movie',
#   'title': 'Secret Magic Control Agency',
#   'director': 'Aleksey Tsitsilin',
#   'country': 'Russia',
#   'date_added': Timestamp('2021-03-25 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '105 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  140: {'index': 6827,
#   'show_id': 's1164',
#   'type': 'TV Show',
#   'title': 'Magic for Humans Spain',
#   'director': 'None',
#   'country': 'Spain',
#   'date_added': Timestamp('2021-03-26 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV, Spanish-Language TV Shows'},
#  141: {'index': 1135,
#   'show_id': 's1166',
#   'type': 'Movie',
#   'title': 'Pagglait',
#   'director': 'Umesh Bist',
#   'country': 'India',
#   'date_added': Timestamp('2021-03-26 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '114 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  142: {'index': 6824,
#   'show_id': 's1158',
#   'type': 'Movie',
#   'title': 'Bad Trip',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-26 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '87 min',
#   'listed_in': 'Comedies'},
#  143: {'index': 1131,
#   'show_id': 's1157',
#   'type': 'Movie',
#   'title': 'A Week Away',
#   'director': 'Roman White',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-26 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '98 min',
#   'listed_in': 'Children & Family Movies, Faith & Spirituality, Music & Musicals'},
#  144: {'index': 6829,
#   'show_id': 's1167',
#   'type': 'TV Show',
#   'title': 'The Irregulars',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-03-26 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, Crime TV Shows, International TV Shows'},
#  145: {'index': 1130,
#   'show_id': 's1156',
#   'type': 'Movie',
#   'title': 'Marked',
#   'director': 'Nadine Ibrahim',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-03-28 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '21 min',
#   'listed_in': 'Documentaries, International Movies'},
#  146: {'index': 1126,
#   'show_id': 's1152',
#   'type': 'Movie',
#   'title': 'Octonauts & the Ring of Fire',
#   'director': 'Blair Simmons',
#   'country': 'China',
#   'date_added': Timestamp('2021-03-30 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y',
#   'duration': '73 min',
#   'listed_in': 'Children & Family Movies'},
#  147: {'index': 1125,
#   'show_id': 's1151',
#   'type': 'Movie',
#   'title': '7 Yards: The Chris Norton Story',
#   'director': 'Jonathon Link',
#   'country': 'United States',
#   'date_added': Timestamp('2021-03-30 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '93 min',
#   'listed_in': 'Documentaries'},
#  148: {'index': 1123,
#   'show_id': 's1147',
#   'type': 'TV Show',
# ...
#  543: {'index': 6591,
#   'show_id': 's96',
#   'type': 'TV Show',
#   'title': 'The Circle',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '3 Seasons',
#   'listed_in': 'Reality TV'},
#  544: {'index': 133,
#   'show_id': 's94',
#   'type': 'Movie',
#   'title': 'JJ+E',
#   'director': 'Alexis Almström',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-08 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '91 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies'},
#  545: {'index': 132,
#   'show_id': 's89',
#   'type': 'Movie',
#   'title': 'Blood Brothers: Malcolm X & Muhammad Ali',
#   'director': 'Marcus Clarke',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-09 00:00:00'),
#   'release_year': 2021,
#   'rating': 'PG-13',
#   'duration': '96 min',
#   'listed_in': 'Documentaries, Sports Movies'},
#  546: {'index': 112,
#   'show_id': 's92',
#   'type': 'Movie',
#   'title': 'The Women and the Murderer',
#   'director': 'Mona Achache, Patricia Tourancheau',
#   'country': 'France',
#   'date_added': Timestamp('2021-09-09 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '92 min',
#   'listed_in': 'Documentaries, International Movies'},
#  547: {'index': 129,
#   'show_id': 's81',
#   'type': 'Movie',
#   'title': 'Firedrake the Silver Dragon',
#   'director': 'Tomer Eshed',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '93 min',
#   'listed_in': 'Children & Family Movies'},
#  548: {'index': 39,
#   'show_id': 's86',
#   'type': 'TV Show',
#   'title': 'Pokémon Master Journeys: The Series',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '1 Season',
#   'listed_in': "Anime Series, Kids' TV"},
#  549: {'index': 38,
#   'show_id': 's84',
#   'type': 'TV Show',
#   'title': 'Metal Shop Masters',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Reality TV'},
#  550: {'index': 6589,
#   'show_id': 's83',
#   'type': 'TV Show',
#   'title': 'Lucifer',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '6 Seasons',
#   'listed_in': 'Crime TV Shows, TV Comedies, TV Dramas'},
#  551: {'index': 108,
#   'show_id': 's87',
#   'type': 'Movie',
#   'title': 'Prey',
#   'director': 'Thomas Sieben',
#   'country': 'Germany',
#   'date_added': Timestamp('2021-09-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '87 min',
#   'listed_in': 'International Movies, Thrillers'},
#  552: {'index': 106,
#   'show_id': 's82',
#   'type': 'Movie',
#   'title': 'Kate',
#   'director': 'Cedric Nicolas-Troyan',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-10 00:00:00'),
#   'release_year': 2021,
#   'rating': 'R',
#   'duration': '106 min',
#   'listed_in': 'Action & Adventure'},
#  553: {'index': 131,
#   'show_id': 's80',
#   'type': 'Movie',
#   'title': 'Tughlaq Durbar (Telugu)',
#   'director': 'Delhiprasad Deenadayalan',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-11 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '145 min',
#   'listed_in': 'Comedies, Dramas, International Movies'},
#  554: {'index': 128,
#   'show_id': 's78',
#   'type': 'Movie',
#   'title': 'Little Singham - Black Shadow',
#   'director': 'Prakash Satam',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-11 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '48 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  555: {'index': 6587,
#   'show_id': 's73',
#   'type': 'TV Show',
#   'title': 'Jack Whitehall: Travels with My Father',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-09-14 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '5 Seasons',
#   'listed_in': 'British TV Shows, Docuseries, International TV Shows'},
#  556: {'index': 37,
#   'show_id': 's75',
#   'type': 'TV Show',
#   'title': "The World's Most Amazing Vacation Rentals",
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-14 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '2 Seasons',
#   'listed_in': 'Reality TV'},
#  557: {'index': 679,
#   'show_id': 's72',
#   'type': 'Movie',
#   'title': 'A StoryBots Space Adventure',
#   'director': 'David A. Vargas',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-14 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y',
#   'duration': '13 min',
#   'listed_in': 'Children & Family Movies'},
#  558: {'index': 59,
#   'show_id': 's76',
#   'type': 'Movie',
#   'title': 'You vs. Wild: Out Cold',
#   'director': 'Ben Simms',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-14 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-G',
#   'duration': '106 min',
#   'listed_in': 'Children & Family Movies'},
#  559: {'index': 6580,
#   'show_id': 's50',
#   'type': 'TV Show',
#   'title': 'Castle and Castle',
#   'director': 'None',
#   'country': 'Nigeria',
#   'date_added': Timestamp('2021-09-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'International TV Shows, TV Dramas'},
#  560: {'index': 6497,
#   'show_id': 's71',
#   'type': 'TV Show',
#   'title': 'Too Hot To Handle: Latino',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV, Romantic TV Shows'},
#  561: {'index': 678,
#   'show_id': 's69',
#   'type': 'Movie',
#   'title': 'Schumacher',
#   'director': 'Hanns-Bruno Kammertöns, Vanessa Nöcker, Michael Wech',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '113 min',
#   'listed_in': 'Documentaries, International Movies, Sports Movies'},
#  562: {'index': 675,
#   'show_id': 's65',
#   'type': 'Movie',
#   'title': 'Nightbooks',
#   'director': 'David Yarovesky',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '103 min',
#   'listed_in': 'Children & Family Movies'},
#  563: {'index': 6582,
#   'show_id': 's66',
#   'type': 'TV Show',
#   'title': 'Numberblocks',
#   'director': 'None',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-09-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y',
#   'duration': '6 Seasons',
#   'listed_in': "Kids' TV"},
#  564: {'index': 73,
#   'show_id': 's56',
#   'type': 'TV Show',
#   'title': 'Nailed It',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-15 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '6 Seasons',
#   'listed_in': 'Reality TV'},
#  565: {'index': 6560,
#   'show_id': 's40',
#   'type': 'TV Show',
#   'title': 'Chhota Bheem',
#   'director': 'Rajiv Chilaka',
#   'country': 'India',
#   'date_added': Timestamp('2021-09-16 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '3 Seasons',
#   'listed_in': "Kids' TV"},
#  566: {'index': 6579,
#   'show_id': 's41',
#   'type': 'TV Show',
#   'title': 'He-Man and the Masters of the Universe',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-16 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y7',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV, TV Sci-Fi & Fantasy"},
#  567: {'index': 80,
#   'show_id': 's46',
#   'type': 'Movie',
#   'title': 'My Heroes Were Cowboys',
#   'director': 'Tyler Greco',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-16 00:00:00'),
#   'release_year': 2021,
#   'rating': 'PG',
#   'duration': '23 min',
#   'listed_in': 'Documentaries'},
#  568: {'index': 34,
#   'show_id': 's32',
#   'type': 'TV Show',
#   'title': 'Chicago Party Aunt',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-17 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies'},
#  569: {'index': 56,
#   'show_id': 's37',
#   'type': 'Movie',
#   'title': 'The Stronghold',
#   'director': 'Cédric Jimenez',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-17 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '105 min',
#   'listed_in': 'Action & Adventure, Dramas, International Movies'},
#  570: {'index': 55,
#   'show_id': 's36',
#   'type': 'Movie',
#   'title': 'The Father Who Moves Mountains',
#   'director': 'Daniel Sandu',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-17 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '110 min',
#   'listed_in': 'Dramas, International Movies, Thrillers'},
#  571: {'index': 54,
#   'show_id': 's31',
#   'type': 'Movie',
#   'title': 'Ankahi Kahaniya',
#   'director': 'Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket Chaudhary',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-17 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '111 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies'},
#  572: {'index': 35,
#   'show_id': 's34',
#   'type': 'TV Show',
#   'title': 'Squid Game',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-17 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas, TV Thrillers'},
#  573: {'index': 28,
#   'show_id': 's24',
#   'type': 'Movie',
#   'title': 'Go! Go! Cory Carson: Chrissy Takes the Wheel',
#   'director': 'Alex Woo, Stanley Moore',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-21 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-Y',
#   'duration': '61 min',
#   'listed_in': 'Children & Family Movies'},
#  574: {'index': 6576,
#   'show_id': 's26',
#   'type': 'TV Show',
#   'title': 'Love on the Spectrum',
#   'director': 'None',
#   'country': 'Australia',
#   'date_added': Timestamp('2021-09-21 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '2 Seasons',
#   'listed_in': 'Docuseries, International TV Shows, Reality TV'},
#  575: {'index': 18,
#   'show_id': 's15',
#   'type': 'TV Show',
#   'title': 'Crime Stories: India Detectives',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-22 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, Crime TV Shows, Docuseries'},
#  576: {'index': 6573,
#   'show_id': 's16',
#   'type': 'TV Show',
#   'title': 'Dear White People',
#   'director': 'None',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-22 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '4 Seasons',
#   'listed_in': 'TV Comedies, TV Dramas'},
#  577: {'index': 27,
#   'show_id': 's21',
#   'type': 'TV Show',
#   'title': 'Monsters Inside: The 24 Faces of Billy Milligan',
#   'director': 'Olivier Megaton',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-22 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries, International TV Shows'},
#  578: {'index': 33,
#   'show_id': 's20',
#   'type': 'TV Show',
#   'title': 'Jaguar',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-22 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Spanish-Language TV Shows, TV Action & Adventure'},
#  579: {'index': 52,
#   'show_id': 's19',
#   'type': 'Movie',
#   'title': 'Intrusion',
#   'director': 'Adam Salky',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-22 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '94 min',
#   'listed_in': 'Thrillers'},
#  580: {'index': 3,
#   'show_id': 's14',
#   'type': 'Movie',
#   'title': 'Confessions of an Invisible Girl',
#   'director': 'Bruno Garotti',
#   'country': 'Brazil',
#   'date_added': Timestamp('2021-09-22 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-PG',
#   'duration': '91 min',
#   'listed_in': 'Children & Family Movies, Comedies'},
#  581: {'index': 24,
#   'show_id': 's12',
#   'type': 'TV Show',
#   'title': 'Bangkok Breaking',
#   'director': 'Kongkiat Komesiri',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-23 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Action & Adventure'},
#  582: {'index': 8,
#   'show_id': 's13',
#   'type': 'Movie',
#   'title': 'Je Suis Karl',
#   'director': 'Christian Schwochow',
#   'country': 'Germany',
#   'date_added': Timestamp('2021-09-23 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '127 min',
#   'listed_in': 'Dramas, International Movies'},
#  583: {'index': 2,
#   'show_id': 's6',
#   'type': 'TV Show',
#   'title': 'Midnight Mass',
#   'director': 'Mike Flanagan',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'TV Dramas, TV Horror, TV Mysteries'},
#  584: {'index': 1,
#   'show_id': 's3',
#   'type': 'TV Show',
#   'title': 'Ganglands',
#   'director': 'Julien Leclercq',
#   'country': 'France',
#   'date_added': Timestamp('2021-09-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, TV Action & Adventure'},
#  585: {'index': 5,
#   'show_id': 's9',
#   'type': 'TV Show',
#   'title': 'The Great British Baking Show',
#   'director': 'Andy Devonshire',
#   'country': 'United Kingdom',
#   'date_added': Timestamp('2021-09-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-14',
#   'duration': '9 Seasons',
#   'listed_in': 'British TV Shows, Reality TV'},
#  586: {'index': 6570,
#   'show_id': 's2',
#   'type': 'TV Show',
#   'title': 'Blood & Water',
#   'director': 'None',
#   'country': 'South Africa',
#   'date_added': Timestamp('2021-09-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'International TV Shows, TV Dramas, TV Mysteries'},
#  587: {'index': 17,
#   'show_id': 's4',
#   'type': 'TV Show',
#   'title': 'Jailbirds New Orleans',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Reality TV'},
#  588: {'index': 23,
#   'show_id': 's7',
#   'type': 'Movie',
#   'title': 'My Little Pony: A New Generation',
#   'director': 'Robert Cullen, José Luis Ucha',
#   'country': 'Not Given',
#   'date_added': Timestamp('2021-09-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'PG',
#   'duration': '91 min',
#   'listed_in': 'Children & Family Movies'},
#  589: {'index': 6572,
#   'show_id': 's5',
#   'type': 'TV Show',
#   'title': 'Kota Factory',
#   'director': 'None',
#   'country': 'India',
#   'date_added': Timestamp('2021-09-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '2 Seasons',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Comedies'},
#  590: {'index': 6586,
#   'show_id': 's11',
#   'type': 'TV Show',
#   'title': 'Vendetta: Truth, Lies and The Mafia',
#   'director': 'None',
#   'country': 'Pakistan',
#   'date_added': Timestamp('2021-09-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, Docuseries, International TV Shows'},
#  591: {'index': 6,
#   'show_id': 's10',
#   'type': 'Movie',
#   'title': 'The Starling',
#   'director': 'Theodore Melfi',
#   'country': 'United States',
#   'date_added': Timestamp('2021-09-24 00:00:00'),
#   'release_year': 2021,
#   'rating': 'PG-13',
#   'duration': '104 min',
#   'listed_in': 'Comedies, Dramas'}}
